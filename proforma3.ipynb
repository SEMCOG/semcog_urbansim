# %%
import numpy as np, pandas as pd
from urbansim.models import MNLLocationChoiceModel, RegressionModelGroup, transition
from developer import developer, feasibility
from urbansim.urbansim import dataset
from variables import var_calc

dset = dataset.Dataset('data//semcog_data.h5')
vacant_residential_units, vacant_job_spaces = var_calc.calculate(dset)
# Out:
# Fetching buildings
# Fetching modify_table
# Fetching parcels
# Fetching modify_table
# Fetching households
# Fetching modify_table
# Fetching jobs
# Fetching modify_table
# Fetching cities
# Fetching modify_table
# Fetching travel_data
# Fetching modify_table
# Fetching building_sqft_per_job
# Fetching modify_table

# %%
print len(dset.parcels)
join_test = pd.merge(dset.parcels, dset.development_constraints,left_on='plan_type_id',right_on='plan_type_id')
# Out:
# 1837676
# Fetching development_constraints
# Fetching modify_table

# %%
parcels = dset.parcels[['parcel_sqft']]
parcels['max_far'] = 1.2
parcels['max_height'] = 100
parcels['max_dua'] = 20
for btype in [16,17,18,19,21,22,23,24,27,28,32,33,39]:
    parcels['type%s'%btype] = 't'
del parcels['parcel_sqft']

# %%
parcels.to_csv('c://semcog_urbansim//data//zoning.csv')

# %%
parcels = pd.read_csv('c://semcog_urbansim//data//zoning.csv').set_index('parcel_id')

# %%
parcels
# Out:
#            max_far  max_height  max_dua type16 type17 type18 type19 type21  \
# parcel_id
# 8182703        1.2         100       20      t      t      t      t      t
# 8182724        1.2         100       20      t      t      t      t      t
# 8182688        1.2         100       20      t      t      t      t      t
# 8182691        1.2         100       20      t      t      t      t      t
# 8182697        1.2         100       20      t      t      t      t      t
# 8182694        1.2         100       20      t      t      t      t      t
# 8182674        1.2         100       20      t      t      t      t      t
# 8182670        1.2         100       20      t      t      t      t      t
# 8182683        1.2         100       20      t      t      t      t      t
# 8182714        1.2         100       20      t      t      t      t      t
# 8182717        1.2         100       20      t      t      t      t      t
# 8182693        1.2         100       20      t      t      t      t      t
# 8182661        1.2         100       20      t      t      t      t      t
# 8182713        1.2         100       20      t      t      t      t      t
# 8182711        1.2         100       20      t      t      t      t      t
# 8182705        1.2         100       20      t      t      t      t      t
# 8182712        1.2         100       20      t      t      t      t      t
# 8182716        1.2         100       20      t      t      t      t      t
# 8182701        1.2         100       20      t      t      t      t      t
# 8182700        1.2         100       20      t      t      t      t      t
# 8182696        1.2         100       20      t      t      t      t      t
# 8182695        1.2         100       20      t      t      t      t      t
# 8182698        1.2         100       20      t      t      t      t      t
# 8182699        1.2         100       20      t      t      t      t      t
# 8182702        1.2         100       20      t      t      t      t      t
# 8182706        1.2         100       20      t      t      t      t      t
# 8182708        1.2         100       20      t      t      t      t      t
# 8182704        1.2         100       20      t      t      t      t      t
# 8182690        1.2         100       20      t      t      t      t      t
# 8182677        1.2         100       20      t      t      t      t      t
# 8182687        1.2         100       20      t      t      t      t      t
# 8182685        1.2         100       20      t      t      t      t      t
# 8182679        1.2         100       20      t      t      t      t      t
# 8182671        1.2         100       20      t      t      t      t      t
# 8183004        1.2         100       20      t      t      t      t      t
# 8183010        1.2         100       20      t      t      t      t      t
# 8182992        1.2         100       20      t      t      t      t      t
# 8182967        1.2         100       20      t      t      t      t      t
# 8182942        1.2         100       20      t      t      t      t      t
# 8182940        1.2         100       20      t      t      t      t      t
# 8182937        1.2         100       20      t      t      t      t      t
# 8182914        1.2         100       20      t      t      t      t      t
# 8182971        1.2         100       20      t      t      t      t      t
# 8182985        1.2         100       20      t      t      t      t      t
# 8182993        1.2         100       20      t      t      t      t      t
# 8182997        1.2         100       20      t      t      t      t      t
# 8183000        1.2         100       20      t      t      t      t      t
# 8183003        1.2         100       20      t      t      t      t      t
# 8183002        1.2         100       20      t      t      t      t      t
# 8182999        1.2         100       20      t      t      t      t      t
# 8182995        1.2         100       20      t      t      t      t      t
# 8182983        1.2         100       20      t      t      t      t      t
# 8182978        1.2         100       20      t      t      t      t      t
# 8182969        1.2         100       20      t      t      t      t      t
# 8182965        1.2         100       20      t      t      t      t      t
# 8182958        1.2         100       20      t      t      t      t      t
# 8182961        1.2         100       20      t      t      t      t      t
# 8182974        1.2         100       20      t      t      t      t      t
# 8182979        1.2         100       20      t      t      t      t      t
# 8182982        1.2         100       20      t      t      t      t      t
#                ...         ...      ...    ...    ...    ...    ...    ...
#
#           type22 type23 type24 type27 type28 type32 type33 type39
# parcel_id
# 8182703        t      t      t      t      t      t      t      t
# 8182724        t      t      t      t      t      t      t      t
# 8182688        t      t      t      t      t      t      t      t
# 8182691        t      t      t      t      t      t      t      t
# 8182697        t      t      t      t      t      t      t      t
# 8182694        t      t      t      t      t      t      t      t
# 8182674        t      t      t      t      t      t      t      t
# 8182670        t      t      t      t      t      t      t      t
# 8182683        t      t      t      t      t      t      t      t
# 8182714        t      t      t      t      t      t      t      t
# 8182717        t      t      t      t      t      t      t      t
# 8182693        t      t      t      t      t      t      t      t
# 8182661        t      t      t      t      t      t      t      t
# 8182713        t      t      t      t      t      t      t      t
# 8182711        t      t      t      t      t      t      t      t
# 8182705        t      t      t      t      t      t      t      t
# 8182712        t      t      t      t      t      t      t      t
# 8182716        t      t      t      t      t      t      t      t
# 8182701        t      t      t      t      t      t      t      t
# 8182700        t      t      t      t      t      t      t      t
# 8182696        t      t      t      t      t      t      t      t
# 8182695        t      t      t      t      t      t      t      t
# 8182698        t      t      t      t      t      t      t      t
# 8182699        t      t      t      t      t      t      t      t
# 8182702        t      t      t      t      t      t      t      t
# 8182706        t      t      t      t      t      t      t      t
# 8182708        t      t      t      t      t      t      t      t
# 8182704        t      t      t      t      t      t      t      t
# 8182690        t      t      t      t      t      t      t      t
# 8182677        t      t      t      t      t      t      t      t
# 8182687        t      t      t      t      t      t      t      t
# 8182685        t      t      t      t      t      t      t      t
# 8182679        t      t      t      t      t      t      t      t
# 8182671        t      t      t      t      t      t      t      t
# 8183004        t      t      t      t      t      t      t      t
# 8183010        t      t      t      t      t      t      t      t
# 8182992        t      t      t      t      t      t      t      t
# 8182967        t      t      t      t      t      t      t      t
# 8182942        t      t      t      t      t      t      t      t
# 8182940        t      t      t      t      t      t      t      t
# 8182937        t      t      t      t      t      t      t      t
# 8182914        t      t      t      t      t      t      t      t
# 8182971        t      t      t      t      t      t      t      t
# 8182985        t      t      t      t      t      t      t      t
# 8182993        t      t      t      t      t      t      t      t
# 8182997        t      t      t      t      t      t      t      t
# 8183000        t      t      t      t      t      t      t      t
# 8183003        t      t      t      t      t      t      t      t
# 8183002        t      t      t      t      t      t      t      t
# 8182999        t      t      t      t      t      t      t      t
# 8182995        t      t      t      t      t      t      t      t
# 8182983        t      t      t      t      t      t      t      t
# 8182978        t      t      t      t      t      t      t      t
# 8182969        t      t      t      t      t      t      t      t
# 8182965        t      t      t      t      t      t      t      t
# 8182958        t      t      t      t      t      t      t      t
# 8182961        t      t      t      t      t      t      t      t
# 8182974        t      t      t      t      t      t      t      t
# 8182979        t      t      t      t      t      t      t      t
# 8182982        t      t      t      t      t      t      t      t
#              ...    ...    ...    ...    ...    ...    ...    ...
#
# [1837676 rows x 16 columns]

# %% [markdown]
# ## Base year estimation

# %%
###HLCM
#Agents for estimation
households_for_estimation = dset.households.loc[np.random.choice(dset.households.index, size=15000, replace=False)]

#Filters on agents
agent_estimation_filters = ['building_id > 0']

agents_simulation_filters = None

##Specification
patsy_expression = ['sqft_per_unit',
                    'income:np.log1p(unit_price_res)',
                    'jobs_within_30_min',
                    'crime08',
                    'popden']
patsy_expression = ' + '.join(patsy_expression)

#Filters on alternatives
estimation_filters = ['building_id > 0']

simulation_filters = ['residential_units>0',
                      'building_type_id in [16,17,18,19,20]']

interaction_filters = ['income*5 > unit_price_res']

##Instantiate HCLM
hlcm = MNLLocationChoiceModel(
    patsy_expression, 10,
    choosers_fit_filters=agent_estimation_filters, choosers_predict_filters=agents_simulation_filters,
    alts_fit_filters=estimation_filters, alts_predict_filters=simulation_filters,interaction_predict_filters=interaction_filters,
    choice_column='building_id', name='HLCM')

##Estimate
hlcm.fit(households_for_estimation, dset.buildings, households_for_estimation.building_id)
hlcm.report_fit()


###ELCM
#Agents for estimation
jobs_for_estimation = dset.jobs_for_estimation

#Filters on agents
agent_estimation_filters = ['home_based_status == 0']

agents_simulation_filters = None

##Specification
patsy_expression = ['np.log1p(non_residential_sqft)',
                    'np.log1p(improvement_value)',
                    'jobs_within_30_min',
                    'popden',
                    'crime08']
patsy_expression = ' + '.join(patsy_expression)

#Filters on alternatives
estimation_filters = ['building_id > 0']

simulation_filters = ['non_residential_sqft>0',
                      'building_type_id not in [16,17,18,19,20]']

##Instantiate ELCM
elcm = MNLLocationChoiceModel(
    patsy_expression, 10,
    choosers_fit_filters=agent_estimation_filters, choosers_predict_filters=agents_simulation_filters,
    alts_fit_filters=estimation_filters, alts_predict_filters=simulation_filters,
    choice_column='building_id', name='ELCM')

##Estimate
elcm.fit(jobs_for_estimation, dset.buildings, jobs_for_estimation.building_id)
elcm.report_fit()



###REPM
##Model specification
def patsy_expression():
    patsy_exp = ['I(year_built < 1940)',
                 'year_built',
                 'stories',
                 'np.log1p(sqft_per_unit)',
                 'np.log1p(popden)',
                 'dist_hwy',
                 'dist_road',
                 'crime08',
                 'np.log1p(jobs_within_30_min)']
    patsy_exp = ' + '.join(patsy_exp)
    return 'np.log(unit_price_res) ~ ' + patsy_exp
model_expression = patsy_expression()

##Estimation filters
estimate_filters = ['residential_units > 0',
                    'sqft_per_unit > 0',
                    'year_built > 1700',
                    'stories > 0',
                    'tax_exempt == 0',
                    '1e5 < unit_price_res < 1e7',
                    '16 <= building_type_id <= 20']

##Simulation filters
simulate_filters = ['residential_units > 0',
                    '16 <= building_type_id <= 20']

##Segmentation
group_keys = [16, 17, 18, 19, 20]
hmg = RegressionModelGroup('building_type_id')
for key in group_keys:
    hmg.add_model_from_params(key, estimate_filters, simulate_filters,
                              model_expression, ytransform=np.exp)
    
##Estimate
fits = hmg.fit(dset.buildings)
# Out:
# Removing 15000 choice situations because chosen alt doesn't exist
# Null Log-liklihood: -34538.776
# Log-liklihood at convergence: -33293.949
# Log-liklihood Ratio: 0.036
#
# +---------------------------------+-------------+------------+---------+
# | Component                       | Coefficient | Std. Error | T-Score |
# +---------------------------------+-------------+------------+---------+
# | sqft_per_unit                   |    -0.000   |   0.000    | -30.282 |
# | income:np.log1p(unit_price_res) |    0.000    |   0.000    | 232.722 |
# | jobs_within_30_min              |    0.000    |   0.000    |  3.355  |
# | crime08                         |    -0.001   |   0.000    |  -3.376 |
# | popden                          |    -0.001   |   0.002    |  -0.603 |
# +---------------------------------+-------------+------------+---------+
# Fetching jobs_for_estimation
# Fetching modify_table
# Removing 48000 choice situations because chosen alt doesn't exist
# Null Log-liklihood: -110524.084
# Log-liklihood at convergence: -15703.384
# Log-liklihood Ratio: 0.858
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_sqft) |    0.623    |   0.003    | 195.018 |
# | np.log1p(improvement_value)    |    0.205    |   0.002    |  84.252 |
# | jobs_within_30_min             |    0.000    |   0.000    |  32.222 |
# | popden                         |    -0.052   |   0.002    | -22.407 |
# | crime08                        |    -0.006   |   0.001    | -11.191 |
# +--------------------------------+-------------+------------+---------+

# %% [markdown]
# ## Model Simulation

# %%
dset.buildings.columns
# Out:
# Index([u'building_id_old', u'building_type_id', u'improvement_value', u'land_area', u'non_residential_sqft', u'parcel_id', u'residential_units', u'sqft_per_unit', u'stories', u'tax_exempt', u'year_built', u'agri_land', u'centroid_x', u'centroid_y', u'city_id', u'county_id', u'dist_hwy', u'dist_road', u'floodprone', u'land_use_type_id', u'land_value', u'large_area_id', u'parcel_sqft', u'plan_id', u'plan_type_id', u'plannew', u'pptytax', u'repm_id', u'school_district_id', u'sewer2010', u'sewer2015', u'sewer2025', u'zone_id', u'unit_price_res', u'unit_price_nonres', u'popden', u'crime08', u'jobs_within_30_min', u'building_sqft_per_job', u'job_spaces', u'building_sqft'], dtype='object')

# %%
for year in range (2011,2013):
    
    vacant_residential_units, vacant_job_spaces = var_calc.calculate(dset)
    
    ##Record county-level hh/job counts
    dset.households['county_id'] = dset.buildings.county_id[dset.households.building_id].values
    dset.jobs['county_id'] = dset.buildings.county_id[dset.jobs.building_id].values
    starting_hh = dset.households.groupby('county_id').size()
    starting_emp = dset.jobs.groupby('county_id').size()
    
    ##Household transition
    ct = dset.fetch('annual_household_control_totals')
    totals_field = ct.reset_index().groupby('year').total_number_of_households.sum()
    ct = pd.DataFrame({'total_number_of_households':totals_field})
    tran = transition.TabularTotalsTransition(ct, 'total_number_of_households')
    model = transition.TransitionModel(tran)
    new, added_hh_idx, new_linked = model.transition(
            dset.households, year, linked_tables={'linked': (dset.persons, 'household_id')})
    dset.households = new
    dset.persons = new_linked['linked']
    
    ##Employment transition
    ct_emp = dset.fetch('annual_employment_control_totals')
    totals_field = ct_emp.reset_index().groupby('year').total_number_of_jobs.sum()
    ct_emp = pd.DataFrame({'total_number_of_jobs':totals_field})
    tran = transition.TabularTotalsTransition(ct_emp, 'total_number_of_jobs')
    model = transition.TransitionModel(tran)
    new, added_jobs_idx, new_linked = model.transition(dset.jobs, year)
    dset.jobs = new
    
    ###HLCM
    new_assignments = hlcm.predict(dset.households.loc[added_hh_idx], vacant_residential_units)
    dset.households.loc[added_hh_idx,'building_id'] = new_assignments
    
    ###ELCM
    new_assignments = elcm.predict(dset.jobs.loc[added_jobs_idx], vacant_job_spaces)
    dset.jobs.loc[added_jobs_idx,'building_id'] = new_assignments
    
    ####REPM
    new_unit_price_res = hmg.predict(dset.buildings)
    dset.buildings.loc[new_unit_price_res.index.values, 'unit_price_res'] = new_unit_price_res
#     dset.buildings = dset.buildings[['building_id_old', 'building_type_id', 'improvement_value', 'land_area',
#          'non_residential_sqft', 'parcel_id', 'residential_units', 'sqft_per_unit',
#          'stories', 'tax_exempt', 'year_built','job_spaces','county_id','zone_id','unit_price_res',
#          'unit_price_nonres','building_sqft']]
    
    ##County-level hh/job growth indicator
    dset.households['county_id'] = dset.buildings.county_id[dset.households.building_id].values
    dset.jobs['county_id'] = dset.buildings.county_id[dset.jobs.building_id].values
    ending_hh = dset.households.groupby('county_id').size()
    ending_emp = dset.jobs.groupby('county_id').size()
    print 'HH diffs'
    print ending_hh - starting_hh
    print 'EMP diffs'
    print ending_emp - starting_emp
    
    
    ####PROFORMA
    feasibility.feasibility_run(dset,year)
    
    ##Record starting non-residential sqft by county
    dset.buildings['county_id'] = dset.parcels.county_id[dset.buildings.parcel_id].values
    starting_nonres = dset.buildings.groupby('county_id').non_residential_sqft.sum()
    
    ##Non-residential proformas
    nr_buildings = developer.exec_developer(dset, year, "jobs", "job_spaces",
                   [21,22,23,24,27,28,32,33,39], nonres=True)
    dset.buildings = dset.buildings[['building_id_old', 'building_type_id', 'improvement_value', 'land_area',
         'non_residential_sqft', 'parcel_id', 'residential_units', 'sqft_per_unit',
         'stories', 'tax_exempt', 'year_built']]
    dset.buildings = pd.concat([dset.buildings,nr_buildings])
    
    ##County-level non-residential-sqft growth indicator
    dset.buildings['county_id'] = dset.parcels.county_id[dset.buildings.parcel_id].values
    ending_nonres = dset.buildings.groupby('county_id').non_residential_sqft.sum()
    print 'Nonres sqft diffs'
    print ending_nonres - starting_nonres
    
    
    ##Record starting residential units by county
    dset.buildings['county_id'] = dset.parcels.county_id[dset.buildings.parcel_id].values
    starting_resunits = dset.buildings.groupby('county_id').residential_units.sum()
    
    ##Residential proformas
    res_buildings = developer.exec_developer(dset, year, "households", "residential_units", [16, 17, 18, 19])
    dset.buildings = pd.concat([dset.buildings,res_buildings])
    
    ##County-level residential unit growth indicator
    dset.buildings['county_id'] = dset.parcels.county_id[dset.buildings.parcel_id].values
    ending_resunits = dset.buildings.groupby('county_id').residential_units.sum()
    print 'Resunit diffs'
    print ending_resunits - starting_resunits
# Out:
# Fetching annual_household_control_totals
# Fetching modify_table
# Fetching persons
# Fetching modify_table
# Fetching annual_employment_control_totals
# Fetching modify_table
# HH diffs
# county_id
# 93            25
# 99           188
# 115           42
# 125          264
# 147           44
# 161           96
# 163          598
# dtype: int64
# EMP diffs
# county_id
# 93             53
# 99            737
# 115            41
# 125          1504
# 147            47
# 161           242
# 163          7051
# dtype: int64
# Running pro forma
#        residential      office      retail  industrial
# count     1.83e+06  1833072.00  1833072.00  1833072.00
# mean      2.23e+08        9.03        9.03        9.03
# std       2.17e+10      121.66      121.66      121.66
# min       3.25e+03       -0.00       -0.00       -0.00
# 25%       8.53e+03        2.32        2.32        2.32
# 50%       9.32e+03        3.51        3.51        3.51
# 75%       1.06e+04        4.70        4.70        4.70
# max       2.12e+12    34872.29    34872.29    34872.29
#
# [8 rows x 4 columns]
# Get zoning:
#  Mon May 19 18:04:58 2014
# residential
#  16
# residential
#  Mon May 19 18:04:59 2014
# sqft cost
# 0.25     20.52
# 0.50     20.52
# 0.75     20.52
# 1.00     22.07
# 1.50     22.81
# 1.80     22.81
# 2.00     24.36
# 3.00     24.36
# 4.00     24.36
# 5.00     26.65
# 7.00     26.65
# 9.00     26.65
# 11.00    30.09
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1    1519482
# dtype: int64
# residential
#  17
# residential
#  Mon May 19 18:05:12 2014
# sqft cost
# 0.25     20.52
# 0.50     20.52
# 0.75     20.52
# 1.00     22.07
# 1.50     22.81
# 1.80     22.81
# 2.00     24.36
# 3.00     24.36
# 4.00     24.36
# 5.00     26.65
# 7.00     26.65
# 9.00     26.65
# 11.00    30.09
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1    1519482
# dtype: int64
# residential
#  18
# residential
#  Mon May 19 18:05:22 2014
# sqft cost
# 0.25     20.52
# 0.50     20.52
# 0.75     20.52
# 1.00     22.07
# 1.50     22.81
# 1.80     22.81
# 2.00     24.36
# 3.00     24.36
# 4.00     24.36
# 5.00     26.65
# 7.00     26.65
# 9.00     26.65
# 11.00    30.09
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1    1519482
# dtype: int64
# residential
#  19
# residential
#  Mon May 19 18:05:33 2014
# sqft cost
# 0.25     20.52
# 0.50     20.52
# 0.75     20.52
# 1.00     22.07
# 1.50     22.81
# 1.80     22.81
# 2.00     24.36
# 3.00     24.36
# 4.00     24.36
# 5.00     26.65
# 7.00     26.65
# 9.00     26.65
# 11.00    30.09
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1    1519482
# dtype: int64
# industrial
#  32
# industrial
#  Mon May 19 18:05:43 2014
# sqft cost
# 0.25     16.67
# 0.50     16.67
# 0.75     16.67
# 1.00     17.60
# 1.50     20.68
# 1.80     20.68
# 2.00     20.68
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.00    2424
# 0.75      40
# dtype: int64
# industrial
#  33
# industrial
#  Mon May 19 18:05:54 2014
# sqft cost
# 0.25     16.67
# 0.50     16.67
# 0.75     16.67
# 1.00     17.60
# 1.50     20.68
# 1.80     20.68
# 2.00     20.68
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.00    2424
# 0.75      40
# dtype: int64
# industrial
#  39
# industrial
#  Mon May 19 18:06:04 2014
# sqft cost
# 0.25     16.67
# 0.50     16.67
# 0.75     16.67
# 1.00     17.60
# 1.50     20.68
# 1.80     20.68
# 2.00     20.68
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.00    2424
# 0.75      40
# dtype: int64
# mixedresidential
#  21
# mixedresidential
#  Mon May 19 18:06:16 2014
# sqft cost
# 0.25     20.51
# 0.50     20.51
# 0.75     20.51
# 1.00     22.21
# 1.50     22.74
# 1.80     24.45
# 2.00     24.45
# 3.00     24.45
# 4.00     24.45
# 5.00     26.80
# 7.00     26.80
# 9.00     26.80
# 11.00    30.23
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1    1515751
# dtype: int64
# office
#  27
# office
#  Mon May 19 18:06:26 2014
# sqft cost
# 0.25     19.37
# 0.50     19.37
# 0.75     19.37
# 1.00     20.92
# 1.50     21.09
# 1.80     21.09
# 2.00     22.64
# 3.00     22.64
# 4.00     22.64
# 5.00     25.51
# 7.00     25.51
# 9.00     25.51
# 11.00    28.94
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.00    2368
# 0.75      30
# dtype: int64
# retail
#  22
# retail
#  Mon May 19 18:06:36 2014
# sqft cost
# 0.25     20.40
# 0.50     20.40
# 0.75     22.12
# 1.00     22.12
# 1.50     25.22
# 1.80     25.22
# 2.00     25.22
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.0    2351
# 0.5      17
# dtype: int64
# retail
#  23
# retail
#  Mon May 19 18:06:47 2014
# sqft cost
# 0.25     20.40
# 0.50     20.40
# 0.75     22.12
# 1.00     22.12
# 1.50     25.22
# 1.80     25.22
# 2.00     25.22
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.0    2351
# 0.5      17
# dtype: int64
# retail
#  24
# retail
#  Mon May 19 18:06:58 2014
# sqft cost
# 0.25     20.40
# 0.50     20.40
# 0.75     22.12
# 1.00     22.12
# 1.50     25.22
# 1.80     25.22
# 2.00     25.22
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.0    2351
# 0.5      17
# dtype: int64
# retail
#  28
# retail
#  Mon May 19 18:07:08 2014
# sqft cost
# 0.25     20.40
# 0.50     20.40
# 0.75     22.12
# 1.00     22.12
# 1.50     25.22
# 1.80     25.22
# 2.00     25.22
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.0    2351
# 0.5      17
# dtype: int64
# Feasibility and zoning
#         total_sqft  total_units  year_built  currentrent  parcelsize  \
# count   1550487.00   1550487.00  1550487.00     1.55e+06    1.84e+06
# mean       3750.15         1.44     1949.66     2.06e+12    6.58e+04
# std       33970.81         8.88      143.39     7.73e+14    6.56e+05
# min           0.00         0.00        0.00     0.00e+00    3.00e+02
# 25%        1068.00         1.00     1942.00     7.62e+06    4.95e+03
# 50%        1481.00         1.00     1958.00     1.10e+07    8.01e+03
# 75%        2131.00         1.00     1979.00     1.68e+07    1.69e+04
# max    10257680.00      1610.00     2009.00     4.56e+17    5.60e+08
#
#        type16_zonedfar  type16_zonedheight  type16_feasiblefar  type16_profit  \
# count         1.84e+06             1837676          1530355.00       1.53e+06
# mean          1.20e+00                 100                0.73       2.10e+14
# std           2.96e-06                   0                0.45       4.99e+16
# min           1.20e+00                 100                0.00       0.00e+00
# 25%           1.20e+00                 100                0.00       0.00e+00
# 50%           1.20e+00                 100                1.00       1.06e+09
# 75%           1.20e+00                 100                1.00       2.36e+09
# max           1.20e+00                 100                1.00       3.17e+19
#
#        type17_zonedfar  type17_zonedheight  type17_feasiblefar  type17_profit  \
# count         1.84e+06             1837676          1530355.00       1.53e+06
# mean          1.20e+00                 100                0.73       2.10e+14
# std           2.96e-06                   0                0.45       4.99e+16
# min           1.20e+00                 100                0.00       0.00e+00
# 25%           1.20e+00                 100                0.00       0.00e+00
# 50%           1.20e+00                 100                1.00       1.06e+09
# 75%           1.20e+00                 100                1.00       2.36e+09
# max           1.20e+00                 100                1.00       3.17e+19
#
#        type18_zonedfar  type18_zonedheight  type18_feasiblefar  type18_profit  \
# count         1.84e+06             1837676          1530355.00       1.53e+06
# mean          1.20e+00                 100                0.73       2.10e+14
# std           2.96e-06                   0                0.45       4.99e+16
# min           1.20e+00                 100                0.00       0.00e+00
# 25%           1.20e+00                 100                0.00       0.00e+00
# 50%           1.20e+00                 100                1.00       1.06e+09
# 75%           1.20e+00                 100                1.00       2.36e+09
# max           1.20e+00                 100                1.00       3.17e+19
#
#        type19_zonedfar  type19_zonedheight  type19_feasiblefar
# count         1.84e+06             1837676          1530355.00 ...
# mean          1.20e+00                 100                0.73 ...
# std           2.96e-06                   0                0.45 ...
# min           1.20e+00                 100                0.00 ...
# 25%           1.20e+00                 100                0.00 ...
# 50%           1.20e+00                 100                1.00 ...
# 75%           1.20e+00                 100                1.00 ...
# max           1.20e+00                 100                1.00 ...
#
# [8 rows x 61 columns]
# Finished developer
#  Mon May 19 18:08:26 2014
# Running developer for jobs
# Number of agents: 1802698
# Number of agent spaces: 4302903
# Current vacancy = 1.00
# Target vacancy = 0.60, target of new units = 203842
# /Users/ejanowicz/Desktop/semcog_urbansim
# Describe of netunits
#        total_sqft  total_units  year_built  currentrent  parcelsize  \
# count  1060842.00   1060842.00  1060842.00     1.06e+06  1060842.00
# mean      2112.01         0.87     1971.32     1.13e+13    18585.13
# std       3742.16         6.91       18.56     9.91e+14    26854.96
# min          0.00         0.00     1945.00     0.00e+00      300.00
# 25%       1105.00         0.00     1955.00     1.55e+08     6359.00
# 50%       1532.00         0.00     1967.00     2.23e+08     9358.00
# 75%       2163.00         0.00     1988.00     3.38e+08    16711.00
# max     212250.00       540.00     2009.00     2.66e+17   199996.00
#
#        type16_zonedfar  type16_zonedheight  type16_feasiblefar  type16_profit  \
# count         1.06e+06             1060842             1060842       1.06e+06
# mean          1.20e+00                 100                   1       1.51e+14
# std           4.65e-06                   0                   0       1.65e+16
# min           1.20e+00                 100                   1       9.88e+06
# 25%           1.20e+00                 100                   1       9.21e+08
# 50%           1.20e+00                 100                   1       1.46e+09
# 75%           1.20e+00                 100                   1       2.93e+09
# max           1.20e+00                 100                   1       8.17e+18
#
#        type17_zonedfar  type17_zonedheight  type17_feasiblefar  type17_profit  \
# count         1.06e+06             1060842             1060842       1.06e+06
# mean          1.20e+00                 100                   1       1.51e+14
# std           4.65e-06                   0                   0       1.65e+16
# min           1.20e+00                 100                   1       9.88e+06
# 25%           1.20e+00                 100                   1       9.21e+08
# 50%           1.20e+00                 100                   1       1.46e+09
# 75%           1.20e+00                 100                   1       2.93e+09
# max           1.20e+00                 100                   1       8.17e+18
#
#        type18_zonedfar  type18_zonedheight  type18_feasiblefar  type18_profit  \
# count         1.06e+06             1060842             1060842       1.06e+06
# mean          1.20e+00                 100                   1       1.51e+14
# std           4.65e-06                   0                   0       1.65e+16
# min           1.20e+00                 100                   1       9.88e+06
# 25%           1.20e+00                 100                   1       9.21e+08
# 50%           1.20e+00                 100                   1       1.46e+09
# 75%           1.20e+00                 100                   1       2.93e+09
# max           1.20e+00                 100                   1       8.17e+18
#
#        type19_zonedfar  type19_zonedheight  type19_feasiblefar
# count         1.06e+06             1060842             1060842 ...
# mean          1.20e+00                 100                   1 ...
# std           4.65e-06                   0                   0 ...
# min           1.20e+00                 100                   1 ...
# 25%           1.20e+00                 100                   1 ...
# 50%           1.20e+00                 100                   1 ...
# 75%           1.20e+00                 100                   1 ...
# max           1.20e+00                 100                   1 ...
#
# [8 rows x 67 columns]
# Describe of buildings built
# count    969.00
# mean       2.46
# std       11.84
# min        0.00
# 25%        0.00
# 50%        0.00
# 75%        0.00
# max      166.00
# Name: total_units, dtype: float64
# Describe of profit
# count    9.69e+02
# mean     1.47e+17
# std      4.67e+17
# min      7.71e+07
# 25%      2.44e+09
# 50%      9.40e+09
# 75%      2.48e+10
# max      7.34e+18
# Name: max_profit, dtype: float64
# Buildings by type
# 21    969
# dtype: int64
# Units by type
# max_btype
# 21           203235
# Name: netunits, dtype: int64
# Nonres sqft diffs
# county_id
# 93            6065198
# 99            5242372
# 115           2839309
# 125          18451363
# 147           5215936
# 161           7467709
# 163           6003419
# Name: non_residential_sqft, dtype: int64
# Running developer for households
# Number of agents: 1844780
# Number of agent spaces: 2224980
# Current vacancy = 1.00
# Target vacancy = 0.20, target of new units = 80995
# /Users/ejanowicz/Desktop/semcog_urbansim
# Describe of netunits
#        total_sqft  total_units  year_built  currentrent  parcelsize  \
# count  1063451.00   1063451.00  1063451.00     1.06e+06  1063451.00
# mean      2119.76         1.07     1971.36     1.12e+13    18550.46
# std       3819.35         2.35       18.58     9.90e+14    26838.84
# min          0.00         0.00     1945.00     0.00e+00      300.00
# 25%       1105.00         1.00     1955.00     1.55e+08     6333.00
# 50%       1533.00         1.00     1967.00     2.23e+08     9335.00
# 75%       2164.00         1.00     1989.00     3.39e+08    16673.00
# max     224306.00       324.00     2009.00     2.66e+17   199996.00
#
#        type16_zonedfar  type16_zonedheight  type16_feasiblefar  type16_profit  \
# count         1.06e+06             1063451             1063451       1.06e+06
# mean          1.20e+00                 100                   1       1.50e+14
# std           4.66e-06                   0                   0       1.65e+16
# min           1.20e+00                 100                   1       8.25e+04
# 25%           1.20e+00                 100                   1       9.17e+08
# 50%           1.20e+00                 100                   1       1.46e+09
# 75%           1.20e+00                 100                   1       2.93e+09
# max           1.20e+00                 100                   1       8.17e+18
#
#        type17_zonedfar  type17_zonedheight  type17_feasiblefar  type17_profit  \
# count         1.06e+06             1063451             1063451       1.06e+06
# mean          1.20e+00                 100                   1       1.50e+14
# std           4.66e-06                   0                   0       1.65e+16
# min           1.20e+00                 100                   1       8.25e+04
# 25%           1.20e+00                 100                   1       9.17e+08
# 50%           1.20e+00                 100                   1       1.46e+09
# 75%           1.20e+00                 100                   1       2.93e+09
# max           1.20e+00                 100                   1       8.17e+18
#
#        type18_zonedfar  type18_zonedheight  type18_feasiblefar  type18_profit  \
# count         1.06e+06             1063451             1063451       1.06e+06
# mean          1.20e+00                 100                   1       1.50e+14
# std           4.66e-06                   0                   0       1.65e+16
# min           1.20e+00                 100                   1       8.25e+04
# 25%           1.20e+00                 100                   1       9.17e+08
# 50%           1.20e+00                 100                   1       1.46e+09
# 75%           1.20e+00                 100                   1       2.93e+09
# max           1.20e+00                 100                   1       8.17e+18
#
#        type19_zonedfar  type19_zonedheight  type19_feasiblefar
# count         1.06e+06             1063451             1063451 ...
# mean          1.20e+00                 100                   1 ...
# std           4.66e-06                   0                   0 ...
# min           1.20e+00                 100                   1 ...
# 25%           1.20e+00                 100                   1 ...
# 50%           1.20e+00                 100                   1 ...
# 75%           1.20e+00                 100                   1 ...
# max           1.20e+00                 100                   1 ...
#
# [8 rows x 67 columns]
# Describe of buildings built
# count    1867.00
# mean        1.34
# std         4.79
# min         0.00
# 25%         1.00
# 50%         1.00
# 75%         1.00
# max        92.00
# Name: total_units, dtype: float64
# Describe of profit
# count    1.87e+03
# mean     8.56e+16
# std      3.85e+17
# min      2.55e+08
# 25%      2.62e+09
# 50%      8.85e+09
# 75%      2.21e+10
# max      8.17e+18
# Name: max_profit, dtype: float64
# Buildings by type
# 16    1867
# dtype: int64
# Units by type
# max_btype
# 16           80984
# Name: netunits, dtype: int64
# Resunit diffs
# county_id
# 93            9976
# 99            8250
# 115           5271
# 125          30896
# 147           7499
# 161          11507
# 163          10089
# Name: residential_units, dtype: int64
# HH diffs
# county_id
# 93             74
# 99            440
# 115            75
# 125           592
# 147            81
# 161           182
# 163          1208
# dtype: int64
# EMP diffs
# county_id
# 93              91
# 99            1292
# 115             88
# 125           2442
# 147             60
# 161            370
# 163          11651
# dtype: int64
#        residential      office      retail  industrial
# count     1.83e+06  1833072.00  1833072.00  1833072.00
# mean      2.23e+08        9.03        9.03        9.03
# std       2.17e+10      121.66      121.66      121.66
# min       3.25e+03       -0.00       -0.00       -0.00
# 25%       8.53e+03        2.32        2.32        2.32
# 50%       9.32e+03        3.51        3.51        3.51
# 75%       1.06e+04        4.70        4.70        4.70
# max       2.12e+12    34872.29    34872.29    34872.29
#
# [8 rows x 4 columns]
# Get zoning:
#  Mon May 19 18:10:59 2014
# residential
#  16
# residential
#  Mon May 19 18:11:00 2014
# sqft cost
# 0.25     20.52
# 0.50     20.52
# 0.75     20.52
# 1.00     22.07
# 1.50     22.81
# 1.80     22.81
# 2.00     24.36
# 3.00     24.36
# 4.00     24.36
# 5.00     26.65
# 7.00     26.65
# 9.00     26.65
# 11.00    30.09
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1    1519482
# dtype: int64
# residential
#  17
# residential
#  Mon May 19 18:11:15 2014
# sqft cost
# 0.25     20.52
# 0.50     20.52
# 0.75     20.52
# 1.00     22.07
# 1.50     22.81
# 1.80     22.81
# 2.00     24.36
# 3.00     24.36
# 4.00     24.36
# 5.00     26.65
# 7.00     26.65
# 9.00     26.65
# 11.00    30.09
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1    1519482
# dtype: int64
# residential
#  18
# residential
#  Mon May 19 18:11:27 2014
# sqft cost
# 0.25     20.52
# 0.50     20.52
# 0.75     20.52
# 1.00     22.07
# 1.50     22.81
# 1.80     22.81
# 2.00     24.36
# 3.00     24.36
# 4.00     24.36
# 5.00     26.65
# 7.00     26.65
# 9.00     26.65
# 11.00    30.09
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1    1519482
# dtype: int64
# residential
#  19
# residential
#  Mon May 19 18:11:40 2014
# sqft cost
# 0.25     20.52
# 0.50     20.52
# 0.75     20.52
# 1.00     22.07
# 1.50     22.81
# 1.80     22.81
# 2.00     24.36
# 3.00     24.36
# 4.00     24.36
# 5.00     26.65
# 7.00     26.65
# 9.00     26.65
# 11.00    30.09
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1    1519482
# dtype: int64
# industrial
#  32
# industrial
#  Mon May 19 18:11:56 2014
# sqft cost
# 0.25     16.67
# 0.50     16.67
# 0.75     16.67
# 1.00     17.60
# 1.50     20.68
# 1.80     20.68
# 2.00     20.68
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.00    2424
# 0.75      40
# dtype: int64
# industrial
#  33
# industrial
#  Mon May 19 18:12:07 2014
# sqft cost
# 0.25     16.67
# 0.50     16.67
# 0.75     16.67
# 1.00     17.60
# 1.50     20.68
# 1.80     20.68
# 2.00     20.68
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.00    2424
# 0.75      40
# dtype: int64
# industrial
#  39
# industrial
#  Mon May 19 18:12:19 2014
# sqft cost
# 0.25     16.67
# 0.50     16.67
# 0.75     16.67
# 1.00     17.60
# 1.50     20.68
# 1.80     20.68
# 2.00     20.68
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.00    2424
# 0.75      40
# dtype: int64
# mixedresidential
#  21
# mixedresidential
#  Mon May 19 18:12:31 2014
# sqft cost
# 0.25     20.51
# 0.50     20.51
# 0.75     20.51
# 1.00     22.21
# 1.50     22.74
# 1.80     24.45
# 2.00     24.45
# 3.00     24.45
# 4.00     24.45
# 5.00     26.80
# 7.00     26.80
# 9.00     26.80
# 11.00    30.23
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1    1515751
# dtype: int64
# office
#  27
# office
#  Mon May 19 18:12:43 2014
# sqft cost
# 0.25     19.37
# 0.50     19.37
# 0.75     19.37
# 1.00     20.92
# 1.50     21.09
# 1.80     21.09
# 2.00     22.64
# 3.00     22.64
# 4.00     22.64
# 5.00     25.51
# 7.00     25.51
# 9.00     25.51
# 11.00    28.94
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.00    2368
# 0.75      30
# dtype: int64
# retail
#  22
# retail
#  Mon May 19 18:12:57 2014
# sqft cost
# 0.25     20.40
# 0.50     20.40
# 0.75     22.12
# 1.00     22.12
# 1.50     25.22
# 1.80     25.22
# 2.00     25.22
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.0    2351
# 0.5      17
# dtype: int64
# retail
#  23
# retail
#  Mon May 19 18:13:10 2014
# sqft cost
# 0.25     20.40
# 0.50     20.40
# 0.75     22.12
# 1.00     22.12
# 1.50     25.22
# 1.80     25.22
# 2.00     25.22
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.0    2351
# 0.5      17
# dtype: int64
# retail
#  24
# retail
#  Mon May 19 18:13:23 2014
# sqft cost
# 0.25     20.40
# 0.50     20.40
# 0.75     22.12
# 1.00     22.12
# 1.50     25.22
# 1.80     25.22
# 2.00     25.22
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.0    2351
# 0.5      17
# dtype: int64
# retail
#  28
# retail
#  Mon May 19 18:13:35 2014
# sqft cost
# 0.25     20.40
# 0.50     20.40
# 0.75     22.12
# 1.00     22.12
# 1.50     25.22
# 1.80     25.22
# 2.00     25.22
# 3.00       NaN
# 4.00       NaN
# 5.00       NaN
# 7.00       NaN
# 9.00       NaN
# 11.00      NaN
# Name: even_rent, dtype: float64
# maxprofit_fars
# 1.0    2351
# 0.5      17
# dtype: int64
# Feasibility and zoning
#         total_sqft  total_units  year_built  currentrent  parcelsize  \
# count   1550487.00   1550487.00  1550487.00     1.55e+06    1.84e+06
# mean       3750.15         1.44     1949.66     2.06e+12    6.58e+04
# std       33970.81         8.88      143.39     7.73e+14    6.56e+05
# min           0.00         0.00        0.00     0.00e+00    3.00e+02
# 25%        1068.00         1.00     1942.00     7.62e+06    4.95e+03
# 50%        1481.00         1.00     1958.00     1.10e+07    8.01e+03
# 75%        2131.00         1.00     1979.00     1.68e+07    1.69e+04
# max    10257680.00      1610.00     2009.00     4.56e+17    5.60e+08
#
#        type16_zonedfar  type16_zonedheight  type16_feasiblefar  type16_profit  \
# count         1.84e+06             1837676          1530355.00       1.53e+06
# mean          1.20e+00                 100                0.73       2.10e+14
# std           2.96e-06                   0                0.45       4.99e+16
# min           1.20e+00                 100                0.00       0.00e+00
# 25%           1.20e+00                 100                0.00       0.00e+00
# 50%           1.20e+00                 100                1.00       1.06e+09
# 75%           1.20e+00                 100                1.00       2.36e+09
# max           1.20e+00                 100                1.00       3.17e+19
#
#        type17_zonedfar  type17_zonedheight  type17_feasiblefar  type17_profit  \
# count         1.84e+06             1837676          1530355.00       1.53e+06
# mean          1.20e+00                 100                0.73       2.10e+14
# std           2.96e-06                   0                0.45       4.99e+16
# min           1.20e+00                 100                0.00       0.00e+00
# 25%           1.20e+00                 100                0.00       0.00e+00
# 50%           1.20e+00                 100                1.00       1.06e+09
# 75%           1.20e+00                 100                1.00       2.36e+09
# max           1.20e+00                 100                1.00       3.17e+19
#
#        type18_zonedfar  type18_zonedheight  type18_feasiblefar  type18_profit  \
# count         1.84e+06             1837676          1530355.00       1.53e+06
# mean          1.20e+00                 100                0.73       2.10e+14
# std           2.96e-06                   0                0.45       4.99e+16
# min           1.20e+00                 100                0.00       0.00e+00
# 25%           1.20e+00                 100                0.00       0.00e+00
# 50%           1.20e+00                 100                1.00       1.06e+09
# 75%           1.20e+00                 100                1.00       2.36e+09
# max           1.20e+00                 100                1.00       3.17e+19
#
#        type19_zonedfar  type19_zonedheight  type19_feasiblefar
# count         1.84e+06             1837676          1530355.00 ...
# mean          1.20e+00                 100                0.73 ...
# std           2.96e-06                   0                0.45 ...
# min           1.20e+00                 100                0.00 ...
# 25%           1.20e+00                 100                0.00 ...
# 50%           1.20e+00                 100                1.00 ...
# 75%           1.20e+00                 100                1.00 ...
# max           1.20e+00                 100                1.00 ...
#
# [8 rows x 61 columns]
# Finished developer
#  Mon May 19 18:15:08 2014
# Running developer for jobs
# Number of agents: 1802698
# Number of agent spaces: 4302903
# Current vacancy = 1.00
# Target vacancy = 0.60, target of new units = 203842
# /Users/ejanowicz/Desktop/semcog_urbansim
# Describe of netunits
#        total_sqft  total_units  year_built  currentrent  parcelsize  \
# count  1060842.00   1060842.00  1060842.00     1.06e+06  1060842.00
# mean      2112.01         0.87     1971.32     1.13e+13    18585.13
# std       3742.16         6.91       18.56     9.91e+14    26854.96
# min          0.00         0.00     1945.00     0.00e+00      300.00
# 25%       1105.00         0.00     1955.00     1.55e+08     6359.00
# 50%       1532.00         0.00     1967.00     2.23e+08     9358.00
# 75%       2163.00         0.00     1988.00     3.38e+08    16711.00
# max     212250.00       540.00     2009.00     2.66e+17   199996.00
#
#        type16_zonedfar  type16_zonedheight  type16_feasiblefar  type16_profit  \
# count         1.06e+06             1060842             1060842       1.06e+06
# mean          1.20e+00                 100                   1       1.51e+14
# std           4.65e-06                   0                   0       1.65e+16
# min           1.20e+00                 100                   1       9.88e+06
# 25%           1.20e+00                 100                   1       9.21e+08
# 50%           1.20e+00                 100                   1       1.46e+09
# 75%           1.20e+00                 100                   1       2.93e+09
# max           1.20e+00                 100                   1       8.17e+18
#
#        type17_zonedfar  type17_zonedheight  type17_feasiblefar  type17_profit  \
# count         1.06e+06             1060842             1060842       1.06e+06
# mean          1.20e+00                 100                   1       1.51e+14
# std           4.65e-06                   0                   0       1.65e+16
# min           1.20e+00                 100                   1       9.88e+06
# 25%           1.20e+00                 100                   1       9.21e+08
# 50%           1.20e+00                 100                   1       1.46e+09
# 75%           1.20e+00                 100                   1       2.93e+09
# max           1.20e+00                 100                   1       8.17e+18
#
#        type18_zonedfar  type18_zonedheight  type18_feasiblefar  type18_profit  \
# count         1.06e+06             1060842             1060842       1.06e+06
# mean          1.20e+00                 100                   1       1.51e+14
# std           4.65e-06                   0                   0       1.65e+16
# min           1.20e+00                 100                   1       9.88e+06
# 25%           1.20e+00                 100                   1       9.21e+08
# 50%           1.20e+00                 100                   1       1.46e+09
# 75%           1.20e+00                 100                   1       2.93e+09
# max           1.20e+00                 100                   1       8.17e+18
#
#        type19_zonedfar  type19_zonedheight  type19_feasiblefar
# count         1.06e+06             1060842             1060842 ...
# mean          1.20e+00                 100                   1 ...
# std           4.65e-06                   0                   0 ...
# min           1.20e+00                 100                   1 ...
# 25%           1.20e+00                 100                   1 ...
# 50%           1.20e+00                 100                   1 ...
# 75%           1.20e+00                 100                   1 ...
# max           1.20e+00                 100                   1 ...
#
# [8 rows x 67 columns]
# Describe of buildings built
# count    965.00
# mean       2.05
# std       11.42
# min        0.00
# 25%        0.00
# 50%        0.00
# 75%        0.00
# max      180.00
# Name: total_units, dtype: float64
# Describe of profit
# count    9.65e+02
# mean     1.48e+17
# std      4.68e+17
# min      2.95e+08
# 25%      2.58e+09
# 50%      8.89e+09
# 75%      2.48e+10
# max      7.34e+18
# Name: max_profit, dtype: float64
# Buildings by type
# 21    965
# dtype: int64
# Units by type
# max_btype
# 21           203537
# Name: netunits, dtype: int64
# Nonres sqft diffs
# county_id
# 93            6914729
# 99            4861153
# 115           2052709
# 125          20386368
# 147           5387137
# 161           6807088
# 163           4850956
# Name: non_residential_sqft, dtype: int64
# Running developer for households
# Number of agents: 1844780
# Number of agent spaces: 2224980
# Current vacancy = 1.00
# Target vacancy = 0.20, target of new units = 80995
# /Users/ejanowicz/Desktop/semcog_urbansim
# Describe of netunits
#        total_sqft  total_units  year_built  currentrent  parcelsize  \
# count  1063451.00   1063451.00  1063451.00     1.06e+06  1063451.00
# mean      2119.76         1.07     1971.36     1.12e+13    18550.46
# std       3819.35         2.35       18.58     9.90e+14    26838.84
# min          0.00         0.00     1945.00     0.00e+00      300.00
# 25%       1105.00         1.00     1955.00     1.55e+08     6333.00
# 50%       1533.00         1.00     1967.00     2.23e+08     9335.00
# 75%       2164.00         1.00     1989.00     3.39e+08    16673.00
# max     224306.00       324.00     2009.00     2.66e+17   199996.00
#
#        type16_zonedfar  type16_zonedheight  type16_feasiblefar  type16_profit  \
# count         1.06e+06             1063451             1063451       1.06e+06
# mean          1.20e+00                 100                   1       1.50e+14
# std           4.66e-06                   0                   0       1.65e+16
# min           1.20e+00                 100                   1       8.25e+04
# 25%           1.20e+00                 100                   1       9.17e+08
# 50%           1.20e+00                 100                   1       1.46e+09
# 75%           1.20e+00                 100                   1       2.93e+09
# max           1.20e+00                 100                   1       8.17e+18
#
#        type17_zonedfar  type17_zonedheight  type17_feasiblefar  type17_profit  \
# count         1.06e+06             1063451             1063451       1.06e+06
# mean          1.20e+00                 100                   1       1.50e+14
# std           4.66e-06                   0                   0       1.65e+16
# min           1.20e+00                 100                   1       8.25e+04
# 25%           1.20e+00                 100                   1       9.17e+08
# 50%           1.20e+00                 100                   1       1.46e+09
# 75%           1.20e+00                 100                   1       2.93e+09
# max           1.20e+00                 100                   1       8.17e+18
#
#        type18_zonedfar  type18_zonedheight  type18_feasiblefar  type18_profit  \
# count         1.06e+06             1063451             1063451       1.06e+06
# mean          1.20e+00                 100                   1       1.50e+14
# std           4.66e-06                   0                   0       1.65e+16
# min           1.20e+00                 100                   1       8.25e+04
# 25%           1.20e+00                 100                   1       9.17e+08
# 50%           1.20e+00                 100                   1       1.46e+09
# 75%           1.20e+00                 100                   1       2.93e+09
# max           1.20e+00                 100                   1       8.17e+18
#
#        type19_zonedfar  type19_zonedheight  type19_feasiblefar
# count         1.06e+06             1063451             1063451 ...
# mean          1.20e+00                 100                   1 ...
# std           4.66e-06                   0                   0 ...
# min           1.20e+00                 100                   1 ...
# 25%           1.20e+00                 100                   1 ...
# 50%           1.20e+00                 100                   1 ...
# 75%           1.20e+00                 100                   1 ...
# max           1.20e+00                 100                   1 ...
#
# [8 rows x 67 columns]
# Describe of buildings built
# count    1837.00
# mean        1.15
# std         2.64
# min         0.00
# 25%         1.00
# 50%         1.00
# 75%         1.00
# max        56.00
# Name: total_units, dtype: float64
# Describe of profit
# count    1.84e+03
# mean     8.69e+16
# std      3.88e+17
# min      7.30e+07
# 25%      2.49e+09
# 50%      8.72e+09
# 75%      2.28e+10
# max      8.17e+18
# Name: max_profit, dtype: float64
# Buildings by type
# 16    1837
# dtype: int64
# Units by type
# max_btype
# 16           80982
# Name: netunits, dtype: int64
# Resunit diffs
# county_id
# 93           12797
# 99            8956
# 115           5140
# 125          28736
# 147           9342
# 161           9209
# 163           8909
# Name: residential_units, dtype: int64
