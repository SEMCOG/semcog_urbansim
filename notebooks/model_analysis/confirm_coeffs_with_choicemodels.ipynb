# %%
import orca
import pandas as pd
from urbansim.models import MNLDiscreteChoiceModel

import models, utils, lcm_utils
from urbansim.utils import misc, networks
import output_indicators
# Out:
# using seed 271828

# %%
import numpy as np
from collections import OrderedDict
from choicemodels import MultinomialLogit
from choicemodels.tools import MergedChoiceTable
# Out:
# /home/janowicz/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
buildings = pd.HDFStore('building_store.h5').buildings

buildings_nonres = buildings[buildings.non_residential_sqft > 0]

jobs = orca.get_table('jobs').to_frame(['sector_id', 'building_id', 'home_based_status'])

jobs.building_id = jobs.building_id.astype('int')

buildings_res = buildings[buildings.residential_units > 0]

hh = orca.get_table('households')
hh_vars = hh.local_columns + ['income_quartile', 'is_race4', 'is_race1', 'is_race2', 'ln_income',
                              'hhsize_lt_3', 'is_young', 'has_children']
hh = hh.to_frame(hh_vars)
# Out:
# variables/variables_demographic.py:81: RuntimeWarning: invalid value encountered in log1p
#   return np.log1p(households.income)

# %%
model_configs = lcm_utils.get_model_category_configs()

for model_category_name, model_category_attributes in model_configs.items():
    if model_category_name == 'elcm':
        for yaml_config in model_category_attributes['config_filenames']:
            print yaml_config
            model = MNLDiscreteChoiceModel.from_yaml(str_or_buffer=misc.config(yaml_config))
            
            # Patsy-form specification
            patsy_str = ' + '
            patsy_str = patsy_str.join(model.model_expression) + ' - 1'
            print patsy_str
            
            # Pylogit-form specification
            vars_for_dict = OrderedDict([(varname, 'all_same') for varname in model.model_expression])
            
            submodel_id = int(yaml_config.split('elcm')[-1].split('.')[0])
            
            choosers = jobs[(jobs.sector_id == submodel_id) & (jobs.home_based_status == 0)]

            choosers = choosers.loc[np.random.choice(
                choosers.index,
                3000, replace=False)]
            
            chosen = choosers['building_id']
            alternatives = buildings_nonres

            data = MergedChoiceTable(observations = choosers,
                                     alternatives = alternatives,
                                     chosen_alternatives = chosen,
                                     sample_size = 15)
            
            model = MultinomialLogit(data = data.to_frame(),
                         observation_id_col = data.observation_id_col, 
                         choice_col = data.choice_col,
                         model_expression = vars_for_dict,
                         alternative_id_col='building_id') #patsy_str
            print model._estimation_engine
            
            results = model.fit()
            print results
            print ''
# Out:
# elcm/regional/elcm2.yaml
# general_type_is_Office + general_type_is_Industrial + b_ln_non_residential_sqft + zones_ln_empden_2 + nodes_drv_log_sum_60min_jobs + building_age + nodes_walk_log_sum_residential_units + sqft_price_nonres - 1
# PyLogit
# Log-likelihood at zero: -8,124.1506
# Initial Log-likelihood: -8,124.1506
# Estimation Time for Point Estimation: 0.42 seconds.
# Final log-likelihood: -6,321.0926
#                      Multinomial Logit Model Regression Results
# ===================================================================================
# Dep. Variable:                      chosen   No. Observations:                3,000
# Model:             Multinomial Logit Model   Df Residuals:                    2,992
# Method:                                MLE   Df Model:                            8
# Date:                     Thu, 21 Jun 2018   Pseudo R-squ.:                   0.222
# Time:                             18:10:18   Pseudo R-bar-squ.:               0.221
# AIC:                            12,658.185   Log-Likelihood:             -6,321.093
# BIC:                            12,706.236   LL-Null:                    -8,124.151
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# general_type_is_Office                   1.2108      0.050     24.296      0.000       1.113       1.309
# general_type_is_Industrial               0.9627      0.053     18.005      0.000       0.858       1.067
# b_ln_non_residential_sqft                0.3079      0.016     18.915      0.000       0.276       0.340
# zones_ln_empden_2                        2.2032      0.079     27.822      0.000       2.048       2.358
# nodes_drv_log_sum_60min_jobs             0.0522      0.077      0.676      0.499      -0.099       0.203
# building_age                            -0.0102      0.001     -9.395      0.000      -0.012      -0.008
# nodes_walk_log_sum_residential_units    -0.0924      0.013     -7.230      0.000      -0.117      -0.067
# sqft_price_nonres                       -0.0018      0.001     -3.563      0.000      -0.003      -0.001
# ========================================================================================================
#
# elcm/regional/elcm3.yaml
# general_type_is_Industrial + b_ln_non_residential_sqft + zones_ln_empden_3 + nodes_walk_log_sum_residential_units + building_age + nodes_walk_office - 1
# PyLogit
# Log-likelihood at zero: -8,124.1506
# Initial Log-likelihood: -8,124.1506
# Estimation Time for Point Estimation: 0.21 seconds.
# Final log-likelihood: -2,980.6268
#                      Multinomial Logit Model Regression Results
# ===================================================================================
# Dep. Variable:                      chosen   No. Observations:                3,000
# Model:             Multinomial Logit Model   Df Residuals:                    2,994
# Method:                                MLE   Df Model:                            6
# Date:                     Thu, 21 Jun 2018   Pseudo R-squ.:                   0.633
# Time:                             18:10:28   Pseudo R-bar-squ.:               0.632
# AIC:                             5,973.254   Log-Likelihood:             -2,980.627
# BIC:                             6,009.292   LL-Null:                    -8,124.151
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# general_type_is_Industrial               2.0263      0.062     32.524      0.000       1.904       2.148
# b_ln_non_residential_sqft                0.8593      0.021     40.956      0.000       0.818       0.900
# zones_ln_empden_3                        0.9103      0.050     18.048      0.000       0.811       1.009
# nodes_walk_log_sum_residential_units    -0.0652      0.018     -3.550      0.000      -0.101      -0.029
# building_age                            -0.0067      0.001     -4.664      0.000      -0.010      -0.004
# nodes_walk_office                        0.0007      0.000      1.492      0.136      -0.000       0.002
# ========================================================================================================
#
# elcm/regional/elcm4.yaml
# general_type_is_Industrial + b_ln_non_residential_sqft + zones_ln_empden_4 + nodes_walk_log_sum_residential_units + building_age + nodes_drv_log_sum_45min_jobs - 1
# PyLogit
# Log-likelihood at zero: -8,124.1506
# Initial Log-likelihood: -8,124.1506
# Estimation Time for Point Estimation: 0.15 seconds.
# Final log-likelihood: -4,858.8234
#                      Multinomial Logit Model Regression Results
# ===================================================================================
# Dep. Variable:                      chosen   No. Observations:                3,000
# Model:             Multinomial Logit Model   Df Residuals:                    2,994
# Method:                                MLE   Df Model:                            6
# Date:                     Thu, 21 Jun 2018   Pseudo R-squ.:                   0.402
# Time:                             18:10:39   Pseudo R-bar-squ.:               0.401
# AIC:                             9,729.647   Log-Likelihood:             -4,858.823
# BIC:                             9,765.685   LL-Null:                    -8,124.151
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# general_type_is_Industrial               0.8207      0.048     17.059      0.000       0.726       0.915
# b_ln_non_residential_sqft                0.6589      0.016     40.260      0.000       0.627       0.691
# zones_ln_empden_4                        2.1414      0.070     30.794      0.000       2.005       2.278
# nodes_walk_log_sum_residential_units    -0.0767      0.015     -5.233      0.000      -0.105      -0.048
# building_age                            -0.0111      0.001     -9.523      0.000      -0.013      -0.009
# nodes_drv_log_sum_45min_jobs             0.0796      0.053      1.491      0.136      -0.025       0.184
# ========================================================================================================
#
# elcm/regional/elcm5.yaml
# general_type_is_Retail + b_ln_non_residential_sqft + zones_ln_empden_5 + nodes_drv_log_sum_45min_jobs + building_age + nodes_walk_ave_income - 1
# PyLogit
# Log-likelihood at zero: -8,124.1506
# Initial Log-likelihood: -8,124.1506
# Estimation Time for Point Estimation: 0.19 seconds.
# Final log-likelihood: -4,250.4557
#                      Multinomial Logit Model Regression Results
# ===================================================================================
# Dep. Variable:                      chosen   No. Observations:                3,000
# Model:             Multinomial Logit Model   Df Residuals:                    2,994
# Method:                                MLE   Df Model:                            6
# Date:                     Thu, 21 Jun 2018   Pseudo R-squ.:                   0.477
# Time:                             18:10:49   Pseudo R-bar-squ.:               0.476
# AIC:                             8,512.911   Log-Likelihood:             -4,250.456
# BIC:                             8,548.950   LL-Null:                    -8,124.151
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# general_type_is_Retail           2.2063      0.059     37.664      0.000       2.092       2.321
# b_ln_non_residential_sqft        0.8103      0.017     46.306      0.000       0.776       0.845
# zones_ln_empden_5                0.8077      0.051     15.992      0.000       0.709       0.907
# nodes_drv_log_sum_45min_jobs     0.0135      0.047      0.291      0.771      -0.078       0.105
# building_age                    -0.0135      0.001    -11.567      0.000      -0.016      -0.011
# nodes_walk_ave_income            0.0025      0.007      0.384      0.701      -0.010       0.015
# ================================================================================================
#
# elcm/regional/elcm6.yaml
# general_type_is_TCU + b_ln_non_residential_sqft + zones_ln_empden_6 + nodes_drv_log_sum_60min_jobs + building_age - 1
# PyLogit
# Log-likelihood at zero: -8,124.1506
# Initial Log-likelihood: -8,124.1506
# Estimation Time for Point Estimation: 0.18 seconds.
# Final log-likelihood: -3,317.2959
#                      Multinomial Logit Model Regression Results
# ===================================================================================
# Dep. Variable:                      chosen   No. Observations:                3,000
# Model:             Multinomial Logit Model   Df Residuals:                    2,995
# Method:                                MLE   Df Model:                            5
# Date:                     Thu, 21 Jun 2018   Pseudo R-squ.:                   0.592
# Time:                             18:11:00   Pseudo R-bar-squ.:               0.591
# AIC:                             6,644.592   Log-Likelihood:             -3,317.296
# BIC:                             6,674.624   LL-Null:                    -8,124.151
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# general_type_is_TCU              1.7715      0.057     31.095      0.000       1.660       1.883
# b_ln_non_residential_sqft        0.6417      0.019     34.341      0.000       0.605       0.678
# zones_ln_empden_6                2.4165      0.080     30.284      0.000       2.260       2.573
# nodes_drv_log_sum_60min_jobs     0.1064      0.099      1.079      0.281      -0.087       0.300
# building_age                    -0.0068      0.001     -4.987      0.000      -0.009      -0.004
# ================================================================================================
#
# elcm/regional/elcm8.yaml
# general_type_is_Office + b_ln_non_residential_sqft + zones_ln_empden_8 + nodes_drv_log_sum_30min_jobs + building_age - 1
# PyLogit
# Log-likelihood at zero: -8,124.1506
# Initial Log-likelihood: -8,124.1506
# Estimation Time for Point Estimation: 0.56 seconds.
# Final log-likelihood: -4,052.4306
#                      Multinomial Logit Model Regression Results
# ===================================================================================
# Dep. Variable:                      chosen   No. Observations:                3,000
# Model:             Multinomial Logit Model   Df Residuals:                    2,995
# Method:                                MLE   Df Model:                            5
# Date:                     Thu, 21 Jun 2018   Pseudo R-squ.:                   0.501
# Time:                             18:11:11   Pseudo R-bar-squ.:               0.501
# AIC:                             8,114.861   Log-Likelihood:             -4,052.431
# BIC:                             8,144.893   LL-Null:                    -8,124.151
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# general_type_is_Office           1.4497      0.052     27.874      0.000       1.348       1.552
# b_ln_non_residential_sqft        0.7023      0.018     39.747      0.000       0.668       0.737
# zones_ln_empden_8                1.8029      0.062     28.943      0.000       1.681       1.925
# nodes_drv_log_sum_30min_jobs     0.0730      0.035      2.112      0.035       0.005       0.141
# building_age                    -0.0089      0.001     -7.600      0.000      -0.011      -0.007
# ================================================================================================
#
# elcm/regional/elcm9.yaml
# general_type_is_Office + b_ln_non_residential_sqft + zones_ln_empden_9 + nodes_drv_log_sum_45min_jobs + building_age + nodes_walk_residential - 1
# PyLogit
# Log-likelihood at zero: -8,124.1506
# Initial Log-likelihood: -8,124.1506
# Estimation Time for Point Estimation: 0.18 seconds.
# Final log-likelihood: -4,210.3731
#                      Multinomial Logit Model Regression Results
# ===================================================================================
# Dep. Variable:                      chosen   No. Observations:                3,000
# Model:             Multinomial Logit Model   Df Residuals:                    2,994
# Method:                                MLE   Df Model:                            6
# Date:                     Thu, 21 Jun 2018   Pseudo R-squ.:                   0.482
# Time:                             18:11:21   Pseudo R-bar-squ.:               0.481
# AIC:                             8,432.746   Log-Likelihood:             -4,210.373
# BIC:                             8,468.784   LL-Null:                    -8,124.151
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# general_type_is_Office           2.2167      0.052     42.308      0.000       2.114       2.319
# b_ln_non_residential_sqft        0.4963      0.018     27.688      0.000       0.461       0.531
# zones_ln_empden_9                0.9478      0.044     21.782      0.000       0.862       1.033
# nodes_drv_log_sum_45min_jobs     0.1030      0.053      1.946      0.052      -0.001       0.207
# building_age                    -0.0144      0.001    -12.007      0.000      -0.017      -0.012
# nodes_walk_residential           0.0019      0.000      6.761      0.000       0.001       0.002
# ================================================================================================
#
# elcm/regional/elcm10.yaml
# general_type_is_Office + b_ln_non_residential_sqft + zones_ln_empden_10 + nodes_drv_log_sum_45min_jobs + building_age + nodes_walk_residential - 1
# PyLogit
# Log-likelihood at zero: -8,124.1506
# Initial Log-likelihood: -8,124.1506
# Estimation Time for Point Estimation: 0.18 seconds.
# Final log-likelihood: -3,287.8802
#                      Multinomial Logit Model Regression Results
# ===================================================================================
# Dep. Variable:                      chosen   No. Observations:                3,000
# Model:             Multinomial Logit Model   Df Residuals:                    2,994
# Method:                                MLE   Df Model:                            6
# Date:                     Thu, 21 Jun 2018   Pseudo R-squ.:                   0.595
# Time:                             18:11:32   Pseudo R-bar-squ.:               0.595
# AIC:                             6,587.760   Log-Likelihood:             -3,287.880
# BIC:                             6,623.799   LL-Null:                    -8,124.151
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# general_type_is_Office           1.8008      0.059     30.677      0.000       1.686       1.916
# b_ln_non_residential_sqft        0.7874      0.020     40.313      0.000       0.749       0.826
# zones_ln_empden_10               1.0195      0.039     25.872      0.000       0.942       1.097
# nodes_drv_log_sum_45min_jobs     0.0552      0.066      0.842      0.400      -0.073       0.184
# building_age                    -0.0120      0.001     -9.281      0.000      -0.015      -0.009
# nodes_walk_residential           0.0001      0.000      0.413      0.679      -0.000       0.001
# ================================================================================================
#
# elcm/regional/elcm11.yaml
# general_type_is_Office + b_ln_non_residential_sqft + zones_ln_empden_11 + nodes_drv_log_sum_30min_jobs + building_age - 1
# PyLogit
# Log-likelihood at zero: -8,124.1506
# Initial Log-likelihood: -8,124.1506
# Estimation Time for Point Estimation: 0.25 seconds.
# Final log-likelihood: -869.8255
#                      Multinomial Logit Model Regression Results
# ===================================================================================
# Dep. Variable:                      chosen   No. Observations:                3,000
# Model:             Multinomial Logit Model   Df Residuals:                    2,995
# Method:                                MLE   Df Model:                            5
# Date:                     Thu, 21 Jun 2018   Pseudo R-squ.:                   0.893
# Time:                             18:11:42   Pseudo R-bar-squ.:               0.892
# AIC:                             1,749.651   Log-Likelihood:               -869.825
# BIC:                             1,779.683   LL-Null:                    -8,124.151
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# general_type_is_Office           0.7326      0.122      5.997      0.000       0.493       0.972
# b_ln_non_residential_sqft        1.0353      0.040     26.106      0.000       0.958       1.113
# zones_ln_empden_11               3.1713      0.130     24.339      0.000       2.916       3.427
# nodes_drv_log_sum_30min_jobs     0.2061      0.091      2.261      0.024       0.027       0.385
# building_age                    -0.0219      0.003     -7.957      0.000      -0.027      -0.017
# ================================================================================================
#
# elcm/regional/elcm14.yaml
# general_type_is_Medical + b_ln_non_residential_sqft + zones_ln_empden_14 + nodes_walk_medical + nodes_drv_log_sum_60min_jobs + nodes_drv_log_sum_20min_pop - 1
# PyLogit
# Log-likelihood at zero: -8,124.1506
# Initial Log-likelihood: -8,124.1506
# Estimation Time for Point Estimation: 0.15 seconds.
# Final log-likelihood: -4,077.3977
#                      Multinomial Logit Model Regression Results
# ===================================================================================
# Dep. Variable:                      chosen   No. Observations:                3,000
# Model:             Multinomial Logit Model   Df Residuals:                    2,994
# Method:                                MLE   Df Model:                            6
# Date:                     Thu, 21 Jun 2018   Pseudo R-squ.:                   0.498
# Time:                             18:11:53   Pseudo R-bar-squ.:               0.497
# AIC:                             8,166.795   Log-Likelihood:             -4,077.398
# BIC:                             8,202.834   LL-Null:                    -8,124.151
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# general_type_is_Medical          3.0200      0.057     53.384      0.000       2.909       3.131
# b_ln_non_residential_sqft        0.5928      0.018     33.182      0.000       0.558       0.628
# zones_ln_empden_14               0.8561      0.047     18.279      0.000       0.764       0.948
# nodes_walk_medical               0.0048      0.000     13.773      0.000       0.004       0.005
# nodes_drv_log_sum_60min_jobs     0.1807      0.148      1.219      0.223      -0.110       0.471
# nodes_drv_log_sum_20min_pop      0.0411      0.052      0.785      0.432      -0.061       0.144
# ================================================================================================
#
# elcm/regional/elcm16.yaml
# general_type_is_Retail + building_type_id_is_26 + b_ln_non_residential_sqft + zones_ln_empden_16 + nodes_drv_log_sum_30min_jobs + building_age - 1
# PyLogit
# Log-likelihood at zero: -8,124.1506
# Initial Log-likelihood: -8,124.1506
# Estimation Time for Point Estimation: 0.14 seconds.
# Final log-likelihood: -4,352.4840
#                      Multinomial Logit Model Regression Results
# ===================================================================================
# Dep. Variable:                      chosen   No. Observations:                3,000
# Model:             Multinomial Logit Model   Df Residuals:                    2,994
# Method:                                MLE   Df Model:                            6
# Date:                     Thu, 21 Jun 2018   Pseudo R-squ.:                   0.464
# Time:                             18:12:03   Pseudo R-bar-squ.:               0.464
# AIC:                             8,716.968   Log-Likelihood:             -4,352.484
# BIC:                             8,753.006   LL-Null:                    -8,124.151
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# general_type_is_Retail           2.0291      0.066     30.939      0.000       1.901       2.158
# building_type_id_is_26           2.4762      0.060     41.247      0.000       2.359       2.594
# b_ln_non_residential_sqft        0.7344      0.019     38.837      0.000       0.697       0.771
# zones_ln_empden_16               0.7158      0.038     19.073      0.000       0.642       0.789
# nodes_drv_log_sum_30min_jobs    -0.0373      0.029     -1.281      0.200      -0.094       0.020
# building_age                    -0.0133      0.001    -13.003      0.000      -0.015      -0.011
# ================================================================================================
#
# elcm/regional/elcm17.yaml
# general_type_is_Retail + general_type_is_Office + b_ln_non_residential_sqft + zones_ln_empden_17 + nodes_drv_log_sum_30min_jobs + building_age - 1
# PyLogit
# Log-likelihood at zero: -8,124.1506
# Initial Log-likelihood: -8,124.1506
# Estimation Time for Point Estimation: 0.12 seconds.
# Final log-likelihood: -7,032.9632
#                      Multinomial Logit Model Regression Results
# ===================================================================================
# Dep. Variable:                      chosen   No. Observations:                3,000
# Model:             Multinomial Logit Model   Df Residuals:                    2,994
# Method:                                MLE   Df Model:                            6
# Date:                     Thu, 21 Jun 2018   Pseudo R-squ.:                   0.134
# Time:                             18:12:14   Pseudo R-bar-squ.:               0.134
# AIC:                            14,077.926   Log-Likelihood:             -7,032.963
# BIC:                            14,113.965   LL-Null:                    -8,124.151
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# general_type_is_Retail           0.8323      0.048     17.436      0.000       0.739       0.926
# general_type_is_Office           0.6635      0.055     11.973      0.000       0.555       0.772
# b_ln_non_residential_sqft        0.4946      0.014     35.106      0.000       0.467       0.522
# zones_ln_empden_17               0.9299      0.055     17.028      0.000       0.823       1.037
# nodes_drv_log_sum_30min_jobs     0.1824      0.028      6.543      0.000       0.128       0.237
# building_age                    -0.0022      0.001     -2.351      0.019      -0.004      -0.000
# ================================================================================================
