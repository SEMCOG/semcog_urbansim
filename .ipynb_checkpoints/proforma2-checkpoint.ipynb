# %%
import numpy as np, pandas as pd
from urbansim.models import MNLLocationChoiceModel, RegressionModelGroup, transition
from developer import developer, feasibility
from urbansim.urbansim import dataset
from variables import var_calc

dset = dataset.Dataset('data//semcog_data.h5')
vacant_residential_units, vacant_job_spaces = var_calc.calculate(dset)
# Out:
# Fetching buildings
# Fetching modify_table
# Fetching parcels
# Fetching modify_table
# Fetching households
# Fetching modify_table
# Fetching jobs
# Fetching modify_table
# Fetching cities
# Fetching modify_table
# Fetching travel_data
# Fetching modify_table
# Fetching building_sqft_per_job
# Fetching modify_table

# %% [markdown]
# ## Base year estimation

# %%
###HLCM
#Agents for estimation
households_for_estimation = dset.households.loc[np.random.choice(dset.households.index, size=15000, replace=False)]

#Filters on agents
agent_estimation_filters = ['building_id > 0']

agents_simulation_filters = None

##Specification
patsy_expression = ['sqft_per_unit',
                    'income:np.log1p(unit_price_res)',
                    'jobs_within_30_min',
                    'crime08',
                    'popden']
patsy_expression = ' + '.join(patsy_expression)

#Filters on alternatives
estimation_filters = ['building_id > 0']

simulation_filters = ['residential_units>0',
                      'building_type_id in [16,17,18,19,20]']

interaction_filters = ['income*5 > unit_price_res']

##Instantiate HCLM
hlcm = MNLLocationChoiceModel(
    patsy_expression, 10,
    choosers_fit_filters=agent_estimation_filters, choosers_predict_filters=agents_simulation_filters,
    alts_fit_filters=estimation_filters, alts_predict_filters=simulation_filters,interaction_predict_filters=interaction_filters,
    choice_column='building_id', name='HLCM')

##Estimate
hlcm.fit(households_for_estimation, dset.buildings, households_for_estimation.building_id)
hlcm.report_fit()


###ELCM
#Agents for estimation
jobs_for_estimation = dset.jobs_for_estimation

#Filters on agents
agent_estimation_filters = ['home_based_status == 0']

agents_simulation_filters = None

##Specification
patsy_expression = ['np.log1p(non_residential_sqft)',
                    'np.log1p(improvement_value)',
                    'jobs_within_30_min',
                    'popden',
                    'crime08']
patsy_expression = ' + '.join(patsy_expression)

#Filters on alternatives
estimation_filters = ['building_id > 0']

simulation_filters = ['non_residential_sqft>0',
                      'building_type_id not in [16,17,18,19,20]']

##Instantiate ELCM
elcm = MNLLocationChoiceModel(
    patsy_expression, 10,
    choosers_fit_filters=agent_estimation_filters, choosers_predict_filters=agents_simulation_filters,
    alts_fit_filters=estimation_filters, alts_predict_filters=simulation_filters,
    choice_column='building_id', name='ELCM')

##Estimate
elcm.fit(jobs_for_estimation, dset.buildings, jobs_for_estimation.building_id)
elcm.report_fit()



###REPM
##Model specification
def patsy_expression():
    patsy_exp = ['I(year_built < 1940)',
                 'year_built',
                 'stories',
                 'np.log1p(sqft_per_unit)',
                 'np.log1p(popden)',
                 'dist_hwy',
                 'dist_road',
                 'crime08',
                 'np.log1p(jobs_within_30_min)']
    patsy_exp = ' + '.join(patsy_exp)
    return 'np.log(unit_price_res) ~ ' + patsy_exp
model_expression = patsy_expression()

##Estimation filters
estimate_filters = ['residential_units > 0',
                    'sqft_per_unit > 0',
                    'year_built > 1700',
                    'stories > 0',
                    'tax_exempt == 0',
                    '1e5 < unit_price_res < 1e7',
                    '16 <= building_type_id <= 20']

##Simulation filters
simulate_filters = ['residential_units > 0',
                    '16 <= building_type_id <= 20']

##Segmentation
group_keys = [16, 17, 18, 19, 20]
hmg = RegressionModelGroup('building_type_id')
for key in group_keys:
    hmg.add_model_from_params(key, estimate_filters, simulate_filters,
                              model_expression, ytransform=np.exp)
    
##Estimate
fits = hmg.fit(dset.buildings)
# Out:
# Removing 15000 choice situations because chosen alt doesn't exist
# Null Log-liklihood: -34538.776
# Log-liklihood at convergence: -33284.307
# Log-liklihood Ratio: 0.036
#
# +---------------------------------+-------------+------------+---------+
# | Component                       | Coefficient | Std. Error | T-Score |
# +---------------------------------+-------------+------------+---------+
# | sqft_per_unit                   |    -0.000   |   0.000    | -22.024 |
# | income:np.log1p(unit_price_res) |    0.000    |   0.000    | 223.382 |
# | jobs_within_30_min              |    0.000    |   0.000    |  3.064  |
# | crime08                         |    0.000    |   0.000    |  0.085  |
# | popden                          |    0.000    |   0.002    |  0.019  |
# +---------------------------------+-------------+------------+---------+
# Fetching jobs_for_estimation
# Fetching modify_table
# Removing 48000 choice situations because chosen alt doesn't exist
# Null Log-liklihood: -110524.084
# Log-liklihood at convergence: -15643.780
# Log-liklihood Ratio: 0.858
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_sqft) |    0.633    |   0.003    | 198.240 |
# | np.log1p(improvement_value)    |    0.205    |   0.002    |  85.273 |
# | jobs_within_30_min             |    0.000    |   0.000    |  30.032 |
# | popden                         |    -0.047   |   0.002    | -20.261 |
# | crime08                        |    -0.006   |   0.001    | -12.129 |
# +--------------------------------+-------------+------------+---------+

# %% [markdown]
# ## Model Simulation

# %%
for year in range (2011,2013):
    
    vacant_residential_units, vacant_job_spaces = var_calc.calculate(dset)
    ##Household transition
    ct = dset.fetch('annual_household_control_totals')
    totals_field = ct.reset_index().groupby('year').total_number_of_households.sum()
    ct = pd.DataFrame({'total_number_of_households':totals_field})
    tran = transition.TabularTotalsTransition(ct, 'total_number_of_households')
    model = transition.TransitionModel(tran)
    new, added_hh_idx, new_linked = model.transition(
            dset.households, year, linked_tables={'linked': (dset.persons, 'household_id')})
    
    dset.households = new
    dset.persons = new_linked['linked']
    
    ##Employment transition
    ct_emp = dset.fetch('annual_employment_control_totals')
    totals_field = ct_emp.reset_index().groupby('year').total_number_of_jobs.sum()
    ct_emp = pd.DataFrame({'total_number_of_jobs':totals_field})
    tran = transition.TabularTotalsTransition(ct_emp, 'total_number_of_jobs')
    model = transition.TransitionModel(tran)
    new, added_jobs_idx, new_linked = model.transition(dset.jobs, year)
    
    dset.jobs = new
    
    ###HLCM
    
    #Simulate
    new_assignments = hlcm.predict(dset.households.loc[added_hh_idx], vacant_residential_units)
    print new_assignments
    dset.households.loc[added_hh_idx,'building_id'] = new_assignments
    
    ###ELCM
    
    #Simulate
    new_assignments = elcm.predict(dset.jobs.loc[added_jobs_idx], vacant_job_spaces)
    print new_assignments
    dset.jobs.loc[added_jobs_idx,'building_id'] = new_assignments
    
    ####REPM
    ##Simulate
    new_unit_price_res = hmg.predict(dset.buildings)
    print new_unit_price_res
    dset.buildings.loc[new_unit_price_res.index.values, 'unit_price_res'] = new_unit_price_res
    dset.buildings = dset.buildings[['building_id_old', 'building_type_id', 'improvement_value', 'land_area',
         'non_residential_sqft', 'parcel_id', 'residential_units', 'sqft_per_unit',
         'stories', 'tax_exempt', 'year_built','job_spaces','county_id']]
    # reload(feasibility)
    # feasibility.feasibility_run(dset,2011)
    
    
    ####PROFORMA
    print dset.buildings.non_residential_sqft.sum()
    dset.buildings['county_id'] = dset.parcels.county_id[dset.buildings.parcel_id].values
    starting_nonres = dset.buildings.groupby('county_id').non_residential_sqft.sum()
    print len(dset.buildings)
    
    reload(developer)
    nr_buildings = developer.exec_developer(dset, year, "jobs", "job_spaces",
                   [21,22,23,24,27,28,32,33,39], nonres=True)
    dset.buildings = dset.buildings[['building_id_old', 'building_type_id', 'improvement_value', 'land_area',
         'non_residential_sqft', 'parcel_id', 'residential_units', 'sqft_per_unit',
         'stories', 'tax_exempt', 'year_built']]
    dset.buildings = pd.concat([dset.buildings,nr_buildings])
    
    print dset.buildings.non_residential_sqft.sum()
    dset.buildings['county_id'] = dset.parcels.county_id[dset.buildings.parcel_id].values
    ending_nonres = dset.buildings.groupby('county_id').non_residential_sqft.sum()
    print ending_nonres - starting_nonres
    print len(dset.buildings)
    
    print dset.buildings.residential_units.sum()
    dset.buildings['county_id'] = dset.parcels.county_id[dset.buildings.parcel_id].values
    starting_resunits = dset.buildings.groupby('county_id').residential_units.sum()
    print len(dset.buildings)
    
    reload(developer)
    res_buildings = developer.exec_developer(dset, year, "households", "residential_units", [16, 17, 18, 19])
    dset.buildings = pd.concat([dset.buildings,res_buildings])
    
    print dset.buildings.residential_units.sum()
    dset.buildings['county_id'] = dset.parcels.county_id[dset.buildings.parcel_id].values
    ending_resunits = dset.buildings.groupby('county_id').residential_units.sum()
    print ending_resunits - starting_resunits
    print len(dset.buildings)
# Out:
# Fetching annual_household_control_totals
# Fetching modify_table
# Fetching persons
# Fetching modify_table
# Fetching annual_employment_control_totals
# Fetching modify_table
# 8406590     453036
# 8406591      36971
# 8406592     661755
# 8406593    1158261
# 8406594     352092
# 8406595     586814
# 8406596     228410
# 8406597     824951
# 8406598     273667
# 8406599     808531
# 8406600     324952
# 8406601    1016305
# 8406602     104283
# 8406603     605145
# 8406604     182686
# ...
# 8407832     273891
# 8407833     200784
# 8407834    2067763
# 8407835    1947367
# 8407836     105451
# 8407837     274630
# 8407838     201511
# 8407839    1087053
# 8407840    2025360
# 8407841     176432
# 8407842    1643603
# 8407843     177534
# 8407844     683720
# 8407845     554233
# 8407846     955046
# Length: 1257, dtype: int64
# 1802699     306820
# 1802700    1102582
# 1802701     280001
# 1802702     305761
# 1802703     283834
# 1802704    1837864
# 1802705     302230
# 1802706     951545
# 1802707     306565
# 1802708     834111
# 1802709    1794916
# 1802710     310778
# 1802711    1568521
# 1802712     284392
# 1802713     299212
# ...
# 1812359    1571150
# 1812360     669483
# 1812361    1292248
# 1812362    1568521
# 1812363     294866
# 1812364     305457
# 1812365    1835602
# 1812366    1537139
# 1812367     276437
# 1812368     307615
# 1812369     288096
# 1812370     277005
# 1812371     310093
# 1812372     410442
# 1812373    1571862
# Length: 9675, dtype: int64
# building_id
# 311297          95694.69
# 311396         118529.73
# 311433          86784.01
# 311497         104063.21
# 311505         123074.00
# 311517         100814.02
# 311520         102737.09
# 311541          81818.04
# 311584          70467.80
# 311589          98886.10
# 311597          95793.41
# 311600         124432.18
# 311607         111219.71
# 311659          91454.30
# 311668         103948.17
# ...
# 2061744        116059.28
# 2061748        190635.10
# 2061877        139886.21
# 2061881        154951.75
# 2062063        150858.39
# 2062246        161597.30
# 2062251        208524.87
# 2062979        194812.62
# 2062990        208823.41
# 2063778        190636.60
# 2063929        212735.37
# 2065253        200873.92
# 2065261        248989.82
# 2065263        225063.97
# 2124316         97445.52
# Length: 1817653, dtype: float64
# 2664194915
# 2122930
# Running developer for jobs
# Number of agents: 1802698
# Number of agent spaces: 4302903
# Current vacancy = 1.00
# Target vacancy = 0.60, target of new units = 203842
# c:\semcog_urbansim
# Describe of netunits
#        total_sqft  total_units  year_built  currentrent  parcelsize  \
# count  1060700.00   1060700.00  1060700.00     1.06e+06  1060700.00
# mean      2110.55         0.86     1971.32     1.69e+08    18584.90
# std       3733.52         6.90       18.56     6.88e+09    26853.96
# min          0.00         0.00     1945.00     0.00e+00      300.00
# 25%       1105.00         0.00     1955.00     5.06e+07     6359.00
# 50%       1532.00         0.00     1967.00     8.87e+07     9358.00
# 75%       2163.00         0.00     1988.00     1.73e+08    16711.00
# max     212250.00       540.00     2009.00     7.04e+12   199996.00
#
#        type16_zonedfar  type16_zonedheight  type16_feasiblefar  type16_profit  \
# count         1.06e+06             1060700             1060700       1.06e+06
# mean          1.20e+00                 100                   1       1.71e+09
# std           4.65e-06                   0                   0       5.00e+09
# min           1.20e+00                 100                   1       1.07e+06
# 25%           1.20e+00                 100                   1       2.88e+08
# 50%           1.20e+00                 100                   1       6.07e+08
# 75%           1.20e+00                 100                   1       1.51e+09
# max           1.20e+00                 100                   1       3.30e+12
#
#        type17_zonedfar  type17_zonedheight  type17_feasiblefar  type17_profit  \
# count         1.06e+06             1060700             1060700       1.06e+06
# mean          1.20e+00                 100                   1       1.71e+09
# std           4.65e-06                   0                   0       5.00e+09
# min           1.20e+00                 100                   1       1.07e+06
# 25%           1.20e+00                 100                   1       2.88e+08
# 50%           1.20e+00                 100                   1       6.07e+08
# 75%           1.20e+00                 100                   1       1.51e+09
# max           1.20e+00                 100                   1       3.30e+12
#
#        type18_zonedfar  type18_zonedheight  type18_feasiblefar  type18_profit  \
# count         1.06e+06             1060700             1060700       1.06e+06
# mean          1.20e+00                 100                   1       1.71e+09
# std           4.65e-06                   0                   0       5.00e+09
# min           1.20e+00                 100                   1       1.07e+06
# 25%           1.20e+00                 100                   1       2.88e+08
# 50%           1.20e+00                 100                   1       6.07e+08
# 75%           1.20e+00                 100                   1       1.51e+09
# max           1.20e+00                 100                   1       3.30e+12
#
#        type19_zonedfar  type19_zonedheight  type19_feasiblefar
# count         1.06e+06             1060700             1060700 ...
# mean          1.20e+00                 100                   1 ...
# std           4.65e-06                   0                   0 ...
# min           1.20e+00                 100                   1 ...
# 25%           1.20e+00                 100                   1 ...
# 50%           1.20e+00                 100                   1 ...
# 75%           1.20e+00                 100                   1 ...
# max           1.20e+00                 100                   1 ...
#
# [8 rows x 67 columns]
# Describe of buildings built
# count    806.00
# mean       2.16
# std       10.63
# min        0.00
# 25%        0.00
# 50%        0.00
# 75%        0.00
# max      136.00
# Name: total_units, dtype: float64
# Describe of profit
# count    8.06e+02
# mean     1.19e+10
# std      8.10e+10
# min      1.26e+08
# 25%      1.65e+09
# 50%      4.79e+09
# 75%      1.09e+10
# max      2.26e+12
# Name: max_profit, dtype: float64
# Buildings by type
# 21    806
# dtype: int64
# Units by type
# max_btype
# 21           203500
# Name: netunits, dtype: int32
# 2715407850
# county_id
# 93            9138893
# 99            5331723
# 115           1268293
# 125          18021732
# 147           3761844
# 161          10524013
# 163           3166437
# Name: non_residential_sqft, dtype: int64
# 2123736
# 2224980
# 2123736
# Running developer for households
# Number of agents: 1844780
# Number of agent spaces: 2224980
# Current vacancy = 1.00
# Target vacancy = 0.20, target of new units = 80995
# c:\semcog_urbansim
# Describe of netunits
#        total_sqft  total_units  year_built  currentrent  parcelsize  \
# count  1063366.00   1063366.00  1063366.00     1.06e+06  1063366.00
# mean      2118.49         1.06     1971.36     1.70e+08    18550.09
# std       3808.51         2.34       18.58     6.87e+09    26838.00
# min          0.00         0.00     1945.00     0.00e+00      300.00
# 25%       1105.00         1.00     1955.00     5.06e+07     6334.00
# 50%       1533.00         1.00     1967.00     8.89e+07     9335.00
# 75%       2164.00         1.00     1989.00     1.73e+08    16673.00
# max     224306.00       324.00     2009.00     7.04e+12   199996.00
#
#        type16_zonedfar  type16_zonedheight  type16_feasiblefar  type16_profit  \
# count         1.06e+06             1063366             1063366       1.06e+06
# mean          1.20e+00                 100                   1       1.70e+09
# std           4.66e-06                   0                   0       4.99e+09
# min           1.20e+00                 100                   1       1.74e+04
# 25%           1.20e+00                 100                   1       2.86e+08
# 50%           1.20e+00                 100                   1       6.04e+08
# 75%           1.20e+00                 100                   1       1.50e+09
# max           1.20e+00                 100                   1       3.30e+12
#
#        type17_zonedfar  type17_zonedheight  type17_feasiblefar  type17_profit  \
# count         1.06e+06             1063366             1063366       1.06e+06
# mean          1.20e+00                 100                   1       1.70e+09
# std           4.66e-06                   0                   0       4.99e+09
# min           1.20e+00                 100                   1       1.74e+04
# 25%           1.20e+00                 100                   1       2.86e+08
# 50%           1.20e+00                 100                   1       6.04e+08
# 75%           1.20e+00                 100                   1       1.50e+09
# max           1.20e+00                 100                   1       3.30e+12
#
#        type18_zonedfar  type18_zonedheight  type18_feasiblefar  type18_profit  \
# count         1.06e+06             1063366             1063366       1.06e+06
# mean          1.20e+00                 100                   1       1.70e+09
# std           4.66e-06                   0                   0       4.99e+09
# min           1.20e+00                 100                   1       1.74e+04
# 25%           1.20e+00                 100                   1       2.86e+08
# 50%           1.20e+00                 100                   1       6.04e+08
# 75%           1.20e+00                 100                   1       1.50e+09
# max           1.20e+00                 100                   1       3.30e+12
#
#        type19_zonedfar  type19_zonedheight  type19_feasiblefar
# count         1.06e+06             1063366             1063366 ...
# mean          1.20e+00                 100                   1 ...
# std           4.66e-06                   0                   0 ...
# min           1.20e+00                 100                   1 ...
# 25%           1.20e+00                 100                   1 ...
# 50%           1.20e+00                 100                   1 ...
# 75%           1.20e+00                 100                   1 ...
# max           1.20e+00                 100                   1 ...
#
# [8 rows x 67 columns]
# Describe of buildings built
# count    1797.00
# mean        1.42
# std         5.93
# min         0.00
# 25%         1.00
# 50%         1.00
# 75%         1.00
# max       143.00
# Name: total_units, dtype: float64
# Describe of profit
# count    1.80e+03
# mean     1.20e+10
# std      8.16e+10
# min      7.76e+07
# 25%      1.54e+09
# 50%      4.84e+09
# 75%      1.14e+10
# max      3.30e+12
# Name: max_profit, dtype: float64
# Buildings by type
# 16    1797
# dtype: int64
# Units by type
# max_btype
# 16           80934
# Name: netunits, dtype: int64
# 2308466
# county_id
# 93           14954
# 99            7110
# 115           2693
# 125          31088
# 147           6123
# 161          14306
# 163           7212
# Name: residential_units, dtype: int64
# 2125533
# 8407847     235732
# 8407848    1482802
# 8407849     852897
# 8407850    1075446
# 8407851    1659534
# 8407852    1292088
# 8407853     441781
# 8407854     184936
# 8407855      36271
# 8407856     528020
# 8407857     562563
# 8407858    2063380
# 8407859    2007969
# 8407860    1674114
# 8407861      61805
# ...
# 8410484    1708109
# 8410485     253991
# 8410486    1064371
# 8410487     274701
# 8410488     460718
# 8410489    1908123
# 8410490      85801
# 8410491    1567970
# 8410492     539282
# 8410493    1950426
# 8410494     218913
# 8410495     352091
# 8410496     564960
# 8410497    2051786
# 8410498    1216898
# Length: 2652, dtype: int64
# 1812374    1064705
# 1812375     306787
# 1812376     308587
# 1812377    1451999
# 1812378     291123
# 1812379     310029
# 1812380     300840
# 1812381     306468
# 1812382     276437
# 1812383     310669
# 1812384    1568521
# 1812385    1532983
# 1812386     309619
# 1812387     283711
# 1812388     277351
# ...
# 1828353     308554
# 1828354    1081278
# 1828355     301255
# 1828356    1568521
# 1828357    1790179
# 1828358    1071749
# 1828359     307374
# 1828360     284394
# 1828361     302223
# 1828362     302172
# 1828363     286188
# 1828364    1237910
# 1828365     276942
# 1828366     302605
# 1828367     851880
# Length: 15994, dtype: int64
# building_id
# 311297          95694.69
# 311396         118529.73
# 311433          86784.01
# 311497         104063.21
# 311505         123074.00
# 311517         100814.02
# 311520         102737.09
# 311541          81818.04
# 311584          70467.80
# 311589          98886.10
# 311597          95793.41
# 311600         124432.18
# 311607         111219.71
# 311659          91454.30
# 311668         103948.17
# ...
# 2061744        116059.28
# 2061748        190635.10
# 2061877        139886.21
# 2061881        154951.75
# 2062063        150858.39
# 2062246        161597.30
# 2062251        208524.87
# 2062979        194812.62
# 2062990        208823.41
# 2063778        190636.60
# 2063929        212735.37
# 2065253        200873.92
# 2065261        248989.82
# 2065263        225063.97
# 2124316         97445.52
# Length: 1817653, dtype: float64
# 2664194915
# 2122930
# Running developer for jobs
# Number of agents: 1802698
# Number of agent spaces: 4302903
# Current vacancy = 1.00
# Target vacancy = 0.60, target of new units = 203842
# c:\semcog_urbansim
# Describe of netunits
#        total_sqft  total_units  year_built  currentrent  parcelsize  \
# count  1060700.00   1060700.00  1060700.00     1.06e+06  1060700.00
# mean      2110.55         0.86     1971.32     1.69e+08    18584.90
# std       3733.52         6.90       18.56     6.88e+09    26853.96
# min          0.00         0.00     1945.00     0.00e+00      300.00
# 25%       1105.00         0.00     1955.00     5.06e+07     6359.00
# 50%       1532.00         0.00     1967.00     8.87e+07     9358.00
# 75%       2163.00         0.00     1988.00     1.73e+08    16711.00
# max     212250.00       540.00     2009.00     7.04e+12   199996.00
#
#        type16_zonedfar  type16_zonedheight  type16_feasiblefar  type16_profit  \
# count         1.06e+06             1060700             1060700       1.06e+06
# mean          1.20e+00                 100                   1       1.71e+09
# std           4.65e-06                   0                   0       5.00e+09
# min           1.20e+00                 100                   1       1.07e+06
# 25%           1.20e+00                 100                   1       2.88e+08
# 50%           1.20e+00                 100                   1       6.07e+08
# 75%           1.20e+00                 100                   1       1.51e+09
# max           1.20e+00                 100                   1       3.30e+12
#
#        type17_zonedfar  type17_zonedheight  type17_feasiblefar  type17_profit  \
# count         1.06e+06             1060700             1060700       1.06e+06
# mean          1.20e+00                 100                   1       1.71e+09
# std           4.65e-06                   0                   0       5.00e+09
# min           1.20e+00                 100                   1       1.07e+06
# 25%           1.20e+00                 100                   1       2.88e+08
# 50%           1.20e+00                 100                   1       6.07e+08
# 75%           1.20e+00                 100                   1       1.51e+09
# max           1.20e+00                 100                   1       3.30e+12
#
#        type18_zonedfar  type18_zonedheight  type18_feasiblefar  type18_profit  \
# count         1.06e+06             1060700             1060700       1.06e+06
# mean          1.20e+00                 100                   1       1.71e+09
# std           4.65e-06                   0                   0       5.00e+09
# min           1.20e+00                 100                   1       1.07e+06
# 25%           1.20e+00                 100                   1       2.88e+08
# 50%           1.20e+00                 100                   1       6.07e+08
# 75%           1.20e+00                 100                   1       1.51e+09
# max           1.20e+00                 100                   1       3.30e+12
#
#        type19_zonedfar  type19_zonedheight  type19_feasiblefar
# count         1.06e+06             1060700             1060700 ...
# mean          1.20e+00                 100                   1 ...
# std           4.65e-06                   0                   0 ...
# min           1.20e+00                 100                   1 ...
# 25%           1.20e+00                 100                   1 ...
# 50%           1.20e+00                 100                   1 ...
# 75%           1.20e+00                 100                   1 ...
# max           1.20e+00                 100                   1 ...
#
# [8 rows x 67 columns]
# Describe of buildings built
# count    905.00
# mean       3.10
# std       17.46
# min        0.00
# 25%        0.00
# 50%        0.00
# 75%        0.00
# max      256.00
# Name: total_units, dtype: float64
# Describe of profit
# count    9.05e+02
# mean     1.05e+10
# std      7.71e+10
# min      1.49e+07
# 25%      1.27e+09
# 50%      3.75e+09
# 75%      9.48e+09
# max      2.26e+12
# Name: max_profit, dtype: float64
# Buildings by type
# 21    905
# dtype: int64
# Units by type
# max_btype
# 21           203434
# Name: netunits, dtype: int32
# 2715642865
# county_id
# 93            9320538
# 99            4815978
# 115           1924209
# 125          18583941
# 147           3684234
# 161           8733525
# 163           4385525
# Name: non_residential_sqft, dtype: int64
# 2123835
# 2224980
# 2123835
# Running developer for households
# Number of agents: 1844780
# Number of agent spaces: 2224980
# Current vacancy = 1.00
# Target vacancy = 0.20, target of new units = 80995
# c:\semcog_urbansim
# Describe of netunits
#        total_sqft  total_units  year_built  currentrent  parcelsize  \
# count  1063366.00   1063366.00  1063366.00     1.06e+06  1063366.00
# mean      2118.49         1.06     1971.36     1.70e+08    18550.09
# std       3808.51         2.34       18.58     6.87e+09    26838.00
# min          0.00         0.00     1945.00     0.00e+00      300.00
# 25%       1105.00         1.00     1955.00     5.06e+07     6334.00
# 50%       1533.00         1.00     1967.00     8.89e+07     9335.00
# 75%       2164.00         1.00     1989.00     1.73e+08    16673.00
# max     224306.00       324.00     2009.00     7.04e+12   199996.00
#
#        type16_zonedfar  type16_zonedheight  type16_feasiblefar  type16_profit  \
# count         1.06e+06             1063366             1063366       1.06e+06
# mean          1.20e+00                 100                   1       1.70e+09
# std           4.66e-06                   0                   0       4.99e+09
# min           1.20e+00                 100                   1       1.74e+04
# 25%           1.20e+00                 100                   1       2.86e+08
# 50%           1.20e+00                 100                   1       6.04e+08
# 75%           1.20e+00                 100                   1       1.50e+09
# max           1.20e+00                 100                   1       3.30e+12
#
#        type17_zonedfar  type17_zonedheight  type17_feasiblefar  type17_profit  \
# count         1.06e+06             1063366             1063366       1.06e+06
# mean          1.20e+00                 100                   1       1.70e+09
# std           4.66e-06                   0                   0       4.99e+09
# min           1.20e+00                 100                   1       1.74e+04
# 25%           1.20e+00                 100                   1       2.86e+08
# 50%           1.20e+00                 100                   1       6.04e+08
# 75%           1.20e+00                 100                   1       1.50e+09
# max           1.20e+00                 100                   1       3.30e+12
#
#        type18_zonedfar  type18_zonedheight  type18_feasiblefar  type18_profit  \
# count         1.06e+06             1063366             1063366       1.06e+06
# mean          1.20e+00                 100                   1       1.70e+09
# std           4.66e-06                   0                   0       4.99e+09
# min           1.20e+00                 100                   1       1.74e+04
# 25%           1.20e+00                 100                   1       2.86e+08
# 50%           1.20e+00                 100                   1       6.04e+08
# 75%           1.20e+00                 100                   1       1.50e+09
# max           1.20e+00                 100                   1       3.30e+12
#
#        type19_zonedfar  type19_zonedheight  type19_feasiblefar
# count         1.06e+06             1063366             1063366 ...
# mean          1.20e+00                 100                   1 ...
# std           4.66e-06                   0                   0 ...
# min           1.20e+00                 100                   1 ...
# 25%           1.20e+00                 100                   1 ...
# 50%           1.20e+00                 100                   1 ...
# 75%           1.20e+00                 100                   1 ...
# max           1.20e+00                 100                   1 ...
#
# [8 rows x 67 columns]
# Describe of buildings built
# count    1776.00
# mean        1.23
# std         5.29
# min         0.00
# 25%         1.00
# 50%         1.00
# 75%         1.00
# max       143.00
# Name: total_units, dtype: float64
# Describe of profit
# count    1.78e+03
# mean     1.13e+10
# std      8.15e+10
# min      1.04e+08
# 25%      1.64e+09
# 50%      4.59e+09
# 75%      1.14e+10
# max      3.30e+12
# Name: max_profit, dtype: float64
# Buildings by type
# 16    1776
# dtype: int64
# Units by type
# max_btype
# 16           80946
# Name: netunits, dtype: int64
# 2308113
# county_id
# 93           12105
# 99            8663
# 115           2614
# 125          33565
# 147           4269
# 161          13836
# 163           8081
# Name: residential_units, dtype: int64
# 2125611

# %%
# vacant_residential_units, vacant_job_spaces = var_calc.calculate(dset)

# ###HLCM
# #Agents for simulation
# hids = np.random.choice(dset.households.index, size=1000, replace=False)

# #Simulate
# new_assignments = hlcm.predict(dset.households.loc[hids], vacant_residential_units)
# print new_assignments

# ###ELCM
# #Agents for simulation
# jids = np.random.choice(dset.jobs.index, size=1000, replace=False)

# #Simulate
# new_assignments = elcm.predict(dset.jobs.loc[jids], vacant_job_spaces)
# print new_assignments

# ####REPM
# ##Simulate
# new_unit_price_res = hmg.predict(dset.buildings)
# print new_unit_price_res
